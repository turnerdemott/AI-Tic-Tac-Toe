# %%
#Import libraries
import re
import random

# %%
#Define global variables

# Visual to logical mapping (letters to state indices)
visual_to_logical = {'A': 9, 'B': 9, 'C': 9, 'D': 9, 'E': 4, 'F': 9, 'G': 9, 'H': 9, 'I': 9}

# Game state string: 'x', 'o', or '-'
state = '---------'

# Turn counter: even = program (x), odd = opponent (o)
turn = 0

# Regex win states for terminal checks
win_patterns = {
    'xxx......': 'x', '...xxx...': 'x', '......xxx': 'x',
    'x..x..x..': 'x', '.x..x..x.': 'x', '..x..x..x': 'x',
    'x...x...x': 'x', '..x.x.x..': 'x',
    'ooo......': 'o', '...ooo...': 'o', '......ooo': 'o',
    'o..o..o..': 'o', '.o..o..o.': 'o', '..o..o..o': 'o',
    'o...o...o': 'o', '..o.o.o..': 'o'
}

# Journal of state transitions for learning
state_history = []

# %%
#Define functions

def orient_board(first_space):
    if first_space in ['A', 'B']:
        visual_to_logical.update({'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6, 'H': 7, 'I': 8})
    elif first_space in ['C', 'F']:
        visual_to_logical.update({'A': 6, 'B': 3, 'C': 0, 'D': 7, 'E': 4, 'F': 1, 'G': 8, 'H': 5, 'I': 2})
    elif first_space in ['I', 'H']:
        visual_to_logical.update({'A': 8, 'B': 7, 'C': 6, 'D': 5, 'E': 4, 'F': 3, 'G': 2, 'H': 1, 'I': 0})
    elif first_space in ['G', 'D']:
        visual_to_logical.update({'A': 2, 'B': 5, 'C': 8, 'D': 1, 'E': 4, 'F': 7, 'G': 0, 'H': 3, 'I': 6})

def display_board():
    values = {k: '-' if visual_to_logical[k] == 9 else state[visual_to_logical[k]] for k in visual_to_logical}
    print('======================')
    print(f"  A: {values['A']} | B: {values['B']} | C: {values['C']}")
    print('-------|------|-------')
    print(f"  D: {values['D']} | E: {values['E']} | F: {values['F']}")
    print('-------|------|-------')
    print(f"  G: {values['G']} | H: {values['H']} | I: {values['I']}")
    print('======================')

def make_move():
    global state
    if (turn % 2) == 0:
        print("Program's move...")
        previous = state
        state = choose_move()
        state_history.append((previous, state))
        if turn == 0 and state != '----x----':
            orient_board('A')
    else:
        display_board()
        while True:
            player_input = input("Your move: ").upper()
            if (player_input in 'ABCDEFGHI' and len(player_input) == 1 and
                (visual_to_logical[player_input] == 9 or state[visual_to_logical[player_input]] == '-')):
                break
            print("You can't move there! Try again.")
        if visual_to_logical[player_input] == 9:
            orient_board(player_input)
        idx = visual_to_logical[player_input]
        state = state[:idx] + 'o' + state[idx+1:]

def choose_move():
    if turn == 8:
        return state.replace('-', 'x')
    options = STM[turn // 2][state]
    r = random.random()
    cumulative = 0.0
    for outcome in options:
        cumulative += options[outcome]
        if r <= cumulative:
            return outcome
    print(f"choose_move(): Probabilities error on state {state}")
    return list(options.keys())[-1]

def update_learning(won):
    for i in range(min(len(state_history), 4)):
        prev_state, chosen_state = state_history[i]
        beta = betaReward if won else -betaPunish
        delta = (1.0 - STM[i][prev_state][chosen_state]) if won else STM[i][prev_state][chosen_state]
        num_options = len(STM[i][prev_state])
        for option in STM[i][prev_state]:
            if option == chosen_state:
                STM[i][prev_state][option] += beta * delta
            else:
                STM[i][prev_state][option] -= beta * delta / (num_options - 1)
    print('The program has learned from this experience :)' if won else 'The program has learned from this experience :(')

def get_branches(start):
    player = 'x' if start.count('x') == start.count('o') else 'o'
    return [start[:i] + player + start[i+1:] for i in range(len(start)) if start[i] == '-']

# %%
#Build the STM
STM = [{'---------': {'x--------': 1/3, '-x-------': 1/3, '----x----': 1/3}}]

#Build STM for turns 2, 4, 6
for _ in range(3):
    new_layer = {}
    for state_dict in STM[-1].values():
        for result in state_dict:
            starts = get_branches(result)
            for s in starts:
                if s.startswith('--') or any(re.search(p, s) for p in win_patterns):
                    continue
                ends = get_branches(s)
                prob = 1.0 / len(ends)
                new_layer[s] = {e: prob for e in ends}
    STM.append(new_layer)

print('STM assembled.')
# Out:
# STM assembled.

# %%
#Set beta values
betaReward = 0.5
betaPunish = 0.25

# %%
#Start a new game

#reset variables
visual_to_logical.update({k: 9 for k in visual_to_logical})
visual_to_logical['E'] = 4
state = '---------'
state_history = []
turn = 0
done = False

ans = input('Print the state Strings? (y/n): ')
print_states = ans.lower().startswith('y')
print('Taking that as a ' + ('yes' if print_states else 'no'))

print("\nLet's play Tic Tac Toe!\n~~~~~~~~~~~~~~~~~~~~~~~")

while True:
    if print_states:
        print('Current state: ' + state)
    for pattern in win_patterns:
        if re.search(pattern, state):
            print('\nGame over! ~~~~~~~~~~~')
            display_board()
            print(win_patterns[pattern] + ' wins!')
            update_learning(win_patterns[pattern] == 'x')
            done = True
            break
    if done:
        break
    if turn >= 9:
        print('\nGame over! ~~~~~~~~~~~')
        display_board()
        print("It's a tie!")
        update_learning(True)
        break
    make_move()
    turn += 1
# Out:
# Print the state Strings? (y/n):  n
# Taking that as a no
#
# Let's play Tic Tac Toe!
# ~~~~~~~~~~~~~~~~~~~~~~~
# Program's move...
# ======================
#   A: x | B: - | C: -
# -------|------|-------
#   D: - | E: - | F: -
# -------|------|-------
#   G: - | H: - | I: -
# ======================
# Your move:  e
# Program's move...
# ======================
#   A: x | B: x | C: -
# -------|------|-------
#   D: - | E: o | F: -
# -------|------|-------
#   G: - | H: - | I: -
# ======================
# Your move:  c
# Program's move...
# ======================
#   A: x | B: x | C: o
# -------|------|-------
#   D: - | E: o | F: x
# -------|------|-------
#   G: - | H: - | I: -
# ======================
# Your move:  g
# Game over! ~~~~~~~~~~~
# ======================
#   A: x | B: x | C: o
# -------|------|-------
#   D: - | E: o | F: x
# -------|------|-------
#   G: o | H: - | I: -
# ======================
# o wins!
# The program has learned from this experience :(

# %%
#Show the STM
show_one_state = False # make true to only STM for one state
specific = '---------'  # a valid 9-char state before x's move

for i, layer in enumerate(STM):
    turn = i * 2
    if show_one_state and (specific.count('x') + specific.count('o')) != turn:
        continue
    print(f'Turn {turn} ====================================')
    for state in layer:
        if show_one_state and state != specific:
            continue
        print(f'{state}:')
        for result, prob in layer[state].items():
            print(f'    {result}: {prob}')
# Out:
# Turn 0 ====================================
# ---------:
#     x--------: 0.28125
#     -x-------: 0.296875
#     ----x----: 0.421875
# Turn 2 ====================================
# xo-------:
#     xox------: 0.14285714285714285
#     xo-x-----: 0.14285714285714285
#     xo--x----: 0.14285714285714285
#     xo---x---: 0.14285714285714285
#     xo----x--: 0.14285714285714285
#     xo-----x-: 0.14285714285714285
#     xo------x: 0.14285714285714285
# x-o------:
#     xxo------: 0.14285714285714285
#     x-ox-----: 0.14285714285714285
#     x-o-x----: 0.14285714285714285
#     x-o--x---: 0.14285714285714285
#     x-o---x--: 0.14285714285714285
#     x-o----x-: 0.14285714285714285
#     x-o-----x: 0.14285714285714285
# x--o-----:
#     xx-o-----: 0.14285714285714285
#     x-xo-----: 0.14285714285714285
#     x--ox----: 0.14285714285714285
#     x--o-x---: 0.14285714285714285
#     x--o--x--: 0.14285714285714285
#     x--o---x-: 0.14285714285714285
#     x--o----x: 0.14285714285714285
# x---o----:
#     xx--o----: 0.10714285714285714
#     x-x-o----: 0.1488095238095238
#     x--xo----: 0.1488095238095238
#     x---ox---: 0.1488095238095238
#     x---o-x--: 0.1488095238095238
#     x---o--x-: 0.1488095238095238
#     x---o---x: 0.1488095238095238
# x----o---:
#     xx---o---: 0.14285714285714285
#     x-x--o---: 0.14285714285714285
#     x--x-o---: 0.14285714285714285
#     x---xo---: 0.14285714285714285
#     x----ox--: 0.14285714285714285
#     x----o-x-: 0.14285714285714285
#     x----o--x: 0.14285714285714285
# x-----o--:
#     xx----o--: 0.14285714285714285
#     x-x---o--: 0.14285714285714285
#     x--x--o--: 0.14285714285714285
#     x---x-o--: 0.14285714285714285
#     x----xo--: 0.14285714285714285
#     x-----ox-: 0.14285714285714285
#     x-----o-x: 0.14285714285714285
# x------o-:
#     xx-----o-: 0.14285714285714285
#     x-x----o-: 0.14285714285714285
#     x--x---o-: 0.14285714285714285
#     x---x--o-: 0.14285714285714285
#     x----x-o-: 0.14285714285714285
#     x-----xo-: 0.14285714285714285
#     x------ox: 0.14285714285714285
# x-------o:
#     xx------o: 0.14285714285714285
#     x-x-----o: 0.14285714285714285
#     x--x----o: 0.14285714285714285
#     x---x---o: 0.14285714285714285
#     x----x--o: 0.14285714285714285
#     x-----x-o: 0.14285714285714285
#     x------xo: 0.14285714285714285
# ox-------:
#     oxx------: 0.14285714285714285
#     ox-x-----: 0.14285714285714285
#     ox--x----: 0.14285714285714285
#     ox---x---: 0.14285714285714285
#     ox----x--: 0.14285714285714285
#     ox-----x-: 0.14285714285714285
#     ox------x: 0.14285714285714285
# -xo------:
#     xxo------: 0.14285714285714285
#     -xox-----: 0.14285714285714285
#     -xo-x----: 0.14285714285714285
#     -xo--x---: 0.14285714285714285
#     -xo---x--: 0.14285714285714285
#     -xo----x-: 0.14285714285714285
#     -xo-----x: 0.14285714285714285
# -x-o-----:
#     xx-o-----: 0.14285714285714285
#     -xxo-----: 0.14285714285714285
#     -x-ox----: 0.14285714285714285
#     -x-o-x---: 0.14285714285714285
#     -x-o--x--: 0.14285714285714285
#     -x-o---x-: 0.14285714285714285
#     -x-o----x: 0.14285714285714285
# -x--o----:
#     xx--o----: 0.1488095238095238
#     -xx-o----: 0.1488095238095238
#     -x-xo----: 0.1488095238095238
#     -x--ox---: 0.1488095238095238
#     -x--o-x--: 0.1488095238095238
#     -x--o--x-: 0.1488095238095238
#     -x--o---x: 0.10714285714285714
# -x---o---:
#     xx---o---: 0.14285714285714285
#     -xx--o---: 0.14285714285714285
#     -x-x-o---: 0.14285714285714285
#     -x--xo---: 0.14285714285714285
#     -x---ox--: 0.14285714285714285
#     -x---o-x-: 0.14285714285714285
#     -x---o--x: 0.14285714285714285
# -x----o--:
#     xx----o--: 0.14285714285714285
#     -xx---o--: 0.14285714285714285
#     -x-x--o--: 0.14285714285714285
#     -x--x-o--: 0.14285714285714285
#     -x---xo--: 0.14285714285714285
#     -x----ox-: 0.14285714285714285
#     -x----o-x: 0.14285714285714285
# -x-----o-:
#     xx-----o-: 0.14285714285714285
#     -xx----o-: 0.14285714285714285
#     -x-x---o-: 0.14285714285714285
#     -x--x--o-: 0.14285714285714285
#     -x---x-o-: 0.14285714285714285
#     -x----xo-: 0.14285714285714285
#     -x-----ox: 0.14285714285714285
# -x------o:
#     xx------o: 0.14285714285714285
#     -xx-----o: 0.14285714285714285
#     -x-x----o: 0.14285714285714285
#     -x--x---o: 0.14285714285714285
#     -x---x--o: 0.14285714285714285
#     -x----x-o: 0.14285714285714285
#     -x-----xo: 0.14285714285714285
# o---x----:
#     ox--x----: 0.14285714285714285
#     o-x-x----: 0.14285714285714285
#     o--xx----: 0.14285714285714285
#     o---xx---: 0.14285714285714285
#     o---x-x--: 0.14285714285714285
#     o---x--x-: 0.14285714285714285
#     o---x---x: 0.14285714285714285
# -o--x----:
#     xo--x----: 0.14285714285714285
#     -ox-x----: 0.14285714285714285
#     -o-xx----: 0.14285714285714285
#     -o--xx---: 0.14285714285714285
#     -o--x-x--: 0.14285714285714285
#     -o--x--x-: 0.14285714285714285
#     -o--x---x: 0.14285714285714285
# Turn 4 ====================================
# xoxo-----:
#     xoxox----: 0.2
#     xoxo-x---: 0.2
#     xoxo--x--: 0.2
#     xoxo---x-: 0.2
#     xoxo----x: 0.2
# xox-o----:
#     xoxxo----: 0.2
#     xox-ox---: 0.2
#     xox-o-x--: 0.2
#     xox-o--x-: 0.2
#     xox-o---x: 0.2
# xox--o---:
#     xoxx-o---: 0.2
#     xox-xo---: 0.2
#     xox--ox--: 0.2
#     xox--o-x-: 0.2
#     xox--o--x: 0.2
# xox---o--:
#     xoxx--o--: 0.2
#     xox-x-o--: 0.2
#     xox--xo--: 0.2
#     xox---ox-: 0.2
#     xox---o-x: 0.2
# xox----o-:
#     xoxx---o-: 0.2
#     xox-x--o-: 0.2
#     xox--x-o-: 0.2
#     xox---xo-: 0.2
#     xox----ox: 0.2
# xox-----o:
#     xoxx----o: 0.2
#     xox-x---o: 0.2
#     xox--x--o: 0.2
#     xox---x-o: 0.2
#     xox----xo: 0.2
# xoox-----:
#     xooxx----: 0.2
#     xoox-x---: 0.2
#     xoox--x--: 0.2
#     xoox---x-: 0.2
#     xoox----x: 0.2
# xo-xo----:
#     xoxxo----: 0.2
#     xo-xox---: 0.2
#     xo-xo-x--: 0.2
#     xo-xo--x-: 0.2
#     xo-xo---x: 0.2
# xo-x-o---:
#     xoxx-o---: 0.2
#     xo-xxo---: 0.2
#     xo-x-ox--: 0.2
#     xo-x-o-x-: 0.2
#     xo-x-o--x: 0.2
# xo-x--o--:
#     xoxx--o--: 0.2
#     xo-xx-o--: 0.2
#     xo-x-xo--: 0.2
#     xo-x--ox-: 0.2
#     xo-x--o-x: 0.2
# xo-x---o-:
#     xoxx---o-: 0.2
#     xo-xx--o-: 0.2
#     xo-x-x-o-: 0.2
#     xo-x--xo-: 0.2
#     xo-x---ox: 0.2
# xo-x----o:
#     xoxx----o: 0.2
#     xo-xx---o: 0.2
#     xo-x-x--o: 0.2
#     xo-x--x-o: 0.2
#     xo-x---xo: 0.2
# xoo-x----:
#     xooxx----: 0.2
#     xoo-xx---: 0.2
#     xoo-x-x--: 0.2
#     xoo-x--x-: 0.2
#     xoo-x---x: 0.2
# xo-ox----:
#     xoxox----: 0.2
#     xo-oxx---: 0.2
#     xo-ox-x--: 0.2
#     xo-ox--x-: 0.2
#     xo-ox---x: 0.2
# xo--xo---:
#     xox-xo---: 0.2
#     xo-xxo---: 0.2
#     xo--xox--: 0.2
#     xo--xo-x-: 0.2
#     xo--xo--x: 0.2
# xo--x-o--:
#     xox-x-o--: 0.2
#     xo-xx-o--: 0.2
#     xo--xxo--: 0.2
#     xo--x-ox-: 0.2
#     xo--x-o-x: 0.2
# xo--x--o-:
#     xox-x--o-: 0.2
#     xo-xx--o-: 0.2
#     xo--xx-o-: 0.2
#     xo--x-xo-: 0.2
#     xo--x--ox: 0.2
# xo--x---o:
#     xox-x---o: 0.2
#     xo-xx---o: 0.2
#     xo--xx--o: 0.2
#     xo--x-x-o: 0.2
#     xo--x--xo: 0.2
# xoo--x---:
#     xoox-x---: 0.2
#     xoo-xx---: 0.2
#     xoo--xx--: 0.2
#     xoo--x-x-: 0.2
#     xoo--x--x: 0.2
# xo-o-x---:
#     xoxo-x---: 0.2
#     xo-oxx---: 0.2
#     xo-o-xx--: 0.2
#     xo-o-x-x-: 0.2
#     xo-o-x--x: 0.2
# xo--ox---:
#     xox-ox---: 0.2
#     xo-xox---: 0.2
#     xo--oxx--: 0.2
#     xo--ox-x-: 0.2
#     xo--ox--x: 0.2
# xo---xo--:
#     xox--xo--: 0.2
#     xo-x-xo--: 0.2
#     xo--xxo--: 0.2
#     xo---xox-: 0.2
#     xo---xo-x: 0.2
# xo---x-o-:
#     xox--x-o-: 0.2
#     xo-x-x-o-: 0.2
#     xo--xx-o-: 0.2
#     xo---xxo-: 0.2
#     xo---x-ox: 0.2
# xo---x--o:
#     xox--x--o: 0.2
#     xo-x-x--o: 0.2
#     xo--xx--o: 0.2
#     xo---xx-o: 0.2
#     xo---x-xo: 0.2
# xoo---x--:
#     xoox--x--: 0.2
#     xoo-x-x--: 0.2
#     xoo--xx--: 0.2
#     xoo---xx-: 0.2
#     xoo---x-x: 0.2
# xo-o--x--:
#     xoxo--x--: 0.2
#     xo-ox-x--: 0.2
#     xo-o-xx--: 0.2
#     xo-o--xx-: 0.2
#     xo-o--x-x: 0.2
# xo--o-x--:
#     xox-o-x--: 0.2
#     xo-xo-x--: 0.2
#     xo--oxx--: 0.2
#     xo--o-xx-: 0.2
#     xo--o-x-x: 0.2
# xo---ox--:
#     xox--ox--: 0.2
#     xo-x-ox--: 0.2
#     xo--xox--: 0.2
#     xo---oxx-: 0.2
#     xo---ox-x: 0.2
# xo----xo-:
#     xox---xo-: 0.2
#     xo-x--xo-: 0.2
#     xo--x-xo-: 0.2
#     xo---xxo-: 0.2
#     xo----xox: 0.2
# xo----x-o:
#     xox---x-o: 0.2
#     xo-x--x-o: 0.2
#     xo--x-x-o: 0.2
#     xo---xx-o: 0.2
#     xo----xxo: 0.2
# xoo----x-:
#     xoox---x-: 0.2
#     xoo-x--x-: 0.2
#     xoo--x-x-: 0.2
#     xoo---xx-: 0.2
#     xoo----xx: 0.2
# xo-o---x-:
#     xoxo---x-: 0.2
#     xo-ox--x-: 0.2
#     xo-o-x-x-: 0.2
#     xo-o--xx-: 0.2
#     xo-o---xx: 0.2
# xo--o--x-:
#     xox-o--x-: 0.2
#     xo-xo--x-: 0.2
#     xo--ox-x-: 0.2
#     xo--o-xx-: 0.2
#     xo--o--xx: 0.2
# xo---o-x-:
#     xox--o-x-: 0.2
#     xo-x-o-x-: 0.2
#     xo--xo-x-: 0.2
#     xo---oxx-: 0.2
#     xo---o-xx: 0.2
# xo----ox-:
#     xox---ox-: 0.2
#     xo-x--ox-: 0.2
#     xo--x-ox-: 0.2
#     xo---xox-: 0.2
#     xo----oxx: 0.2
# xo-----xo:
#     xox----xo: 0.2
#     xo-x---xo: 0.2
#     xo--x--xo: 0.2
#     xo---x-xo: 0.2
#     xo----xxo: 0.2
# xoo-----x:
#     xoox----x: 0.2
#     xoo-x---x: 0.2
#     xoo--x--x: 0.2
#     xoo---x-x: 0.2
#     xoo----xx: 0.2
# xo-o----x:
#     xoxo----x: 0.2
#     xo-ox---x: 0.2
#     xo-o-x--x: 0.2
#     xo-o--x-x: 0.2
#     xo-o---xx: 0.2
# xo--o---x:
#     xox-o---x: 0.2
#     xo-xo---x: 0.2
#     xo--ox--x: 0.2
#     xo--o-x-x: 0.2
#     xo--o--xx: 0.2
# xo---o--x:
#     xox--o--x: 0.2
#     xo-x-o--x: 0.2
#     xo--xo--x: 0.2
#     xo---ox-x: 0.2
#     xo---o-xx: 0.2
# xo----o-x:
#     xox---o-x: 0.2
#     xo-x--o-x: 0.2
#     xo--x-o-x: 0.2
#     xo---xo-x: 0.2
#     xo----oxx: 0.2
# xo-----ox:
#     xox----ox: 0.2
#     xo-x---ox: 0.2
#     xo--x--ox: 0.2
#     xo---x-ox: 0.2
#     xo----xox: 0.2
# xxoo-----:
#     xxoox----: 0.2
#     xxoo-x---: 0.2
#     xxoo--x--: 0.2
#     xxoo---x-: 0.2
#     xxoo----x: 0.2
# xxo-o----:
#     xxoxo----: 0.21250000000000002
#     xxo-ox---: 0.15000000000000002
#     xxo-o-x--: 0.21250000000000002
#     xxo-o--x-: 0.21250000000000002
#     xxo-o---x: 0.21250000000000002
# xxo--o---:
#     xxox-o---: 0.2
#     xxo-xo---: 0.2
#     xxo--ox--: 0.2
#     xxo--o-x-: 0.2
#     xxo--o--x: 0.2
# xxo---o--:
#     xxox--o--: 0.2
#     xxo-x-o--: 0.2
#     xxo--xo--: 0.2
#     xxo---ox-: 0.2
#     xxo---o-x: 0.2
# xxo----o-:
#     xxox---o-: 0.2
#     xxo-x--o-: 0.2
#     xxo--x-o-: 0.2
#     xxo---xo-: 0.2
#     xxo----ox: 0.2
# xxo-----o:
#     xxox----o: 0.2
#     xxo-x---o: 0.2
#     xxo--x--o: 0.2
#     xxo---x-o: 0.2
#     xxo----xo: 0.2
# x-oxo----:
#     xxoxo----: 0.2
#     x-oxox---: 0.2
#     x-oxo-x--: 0.2
#     x-oxo--x-: 0.2
#     x-oxo---x: 0.2
# x-ox-o---:
#     xxox-o---: 0.2
#     x-oxxo---: 0.2
#     x-ox-ox--: 0.2
#     x-ox-o-x-: 0.2
#     x-ox-o--x: 0.2
# x-ox--o--:
#     xxox--o--: 0.2
#     x-oxx-o--: 0.2
#     x-ox-xo--: 0.2
#     x-ox--ox-: 0.2
#     x-ox--o-x: 0.2
# x-ox---o-:
#     xxox---o-: 0.2
#     x-oxx--o-: 0.2
#     x-ox-x-o-: 0.2
#     x-ox--xo-: 0.2
#     x-ox---ox: 0.2
# x-ox----o:
#     xxox----o: 0.2
#     x-oxx---o: 0.2
#     x-ox-x--o: 0.2
#     x-ox--x-o: 0.2
#     x-ox---xo: 0.2
# x-oox----:
#     xxoox----: 0.2
#     x-ooxx---: 0.2
#     x-oox-x--: 0.2
#     x-oox--x-: 0.2
#     x-oox---x: 0.2
# x-o-xo---:
#     xxo-xo---: 0.2
#     x-oxxo---: 0.2
#     x-o-xox--: 0.2
#     x-o-xo-x-: 0.2
#     x-o-xo--x: 0.2
# x-o-x-o--:
#     xxo-x-o--: 0.2
#     x-oxx-o--: 0.2
#     x-o-xxo--: 0.2
#     x-o-x-ox-: 0.2
#     x-o-x-o-x: 0.2
# x-o-x--o-:
#     xxo-x--o-: 0.2
#     x-oxx--o-: 0.2
#     x-o-xx-o-: 0.2
#     x-o-x-xo-: 0.2
#     x-o-x--ox: 0.2
# x-o-x---o:
#     xxo-x---o: 0.2
#     x-oxx---o: 0.2
#     x-o-xx--o: 0.2
#     x-o-x-x-o: 0.2
#     x-o-x--xo: 0.2
# x-oo-x---:
#     xxoo-x---: 0.2
#     x-ooxx---: 0.2
#     x-oo-xx--: 0.2
#     x-oo-x-x-: 0.2
#     x-oo-x--x: 0.2
# x-o-ox---:
#     xxo-ox---: 0.2
#     x-oxox---: 0.2
#     x-o-oxx--: 0.2
#     x-o-ox-x-: 0.2
#     x-o-ox--x: 0.2
# x-o--xo--:
#     xxo--xo--: 0.2
#     x-ox-xo--: 0.2
#     x-o-xxo--: 0.2
#     x-o--xox-: 0.2
#     x-o--xo-x: 0.2
# x-o--x-o-:
#     xxo--x-o-: 0.2
#     x-ox-x-o-: 0.2
#     x-o-xx-o-: 0.2
#     x-o--xxo-: 0.2
#     x-o--x-ox: 0.2
# x-o--x--o:
#     xxo--x--o: 0.2
#     x-ox-x--o: 0.2
#     x-o-xx--o: 0.2
#     x-o--xx-o: 0.2
#     x-o--x-xo: 0.2
# x-oo--x--:
#     xxoo--x--: 0.2
#     x-oox-x--: 0.2
#     x-oo-xx--: 0.2
#     x-oo--xx-: 0.2
#     x-oo--x-x: 0.2
# x-o-o-x--:
#     xxo-o-x--: 0.2
#     x-oxo-x--: 0.2
#     x-o-oxx--: 0.2
#     x-o-o-xx-: 0.2
#     x-o-o-x-x: 0.2
# x-o--ox--:
#     xxo--ox--: 0.2
#     x-ox-ox--: 0.2
#     x-o-xox--: 0.2
#     x-o--oxx-: 0.2
#     x-o--ox-x: 0.2
# x-o---xo-:
#     xxo---xo-: 0.2
#     x-ox--xo-: 0.2
#     x-o-x-xo-: 0.2
#     x-o--xxo-: 0.2
#     x-o---xox: 0.2
# x-o---x-o:
#     xxo---x-o: 0.2
#     x-ox--x-o: 0.2
#     x-o-x-x-o: 0.2
#     x-o--xx-o: 0.2
#     x-o---xxo: 0.2
# x-oo---x-:
#     xxoo---x-: 0.2
#     x-oox--x-: 0.2
#     x-oo-x-x-: 0.2
#     x-oo--xx-: 0.2
#     x-oo---xx: 0.2
# x-o-o--x-:
#     xxo-o--x-: 0.2
#     x-oxo--x-: 0.2
#     x-o-ox-x-: 0.2
#     x-o-o-xx-: 0.2
#     x-o-o--xx: 0.2
# x-o--o-x-:
#     xxo--o-x-: 0.2
#     x-ox-o-x-: 0.2
#     x-o-xo-x-: 0.2
#     x-o--oxx-: 0.2
#     x-o--o-xx: 0.2
# x-o---ox-:
#     xxo---ox-: 0.2
#     x-ox--ox-: 0.2
#     x-o-x-ox-: 0.2
#     x-o--xox-: 0.2
#     x-o---oxx: 0.2
# x-o----xo:
#     xxo----xo: 0.2
#     x-ox---xo: 0.2
#     x-o-x--xo: 0.2
#     x-o--x-xo: 0.2
#     x-o---xxo: 0.2
# x-oo----x:
#     xxoo----x: 0.2
#     x-oox---x: 0.2
#     x-oo-x--x: 0.2
#     x-oo--x-x: 0.2
#     x-oo---xx: 0.2
# x-o-o---x:
#     xxo-o---x: 0.2
#     x-oxo---x: 0.2
#     x-o-ox--x: 0.2
#     x-o-o-x-x: 0.2
#     x-o-o--xx: 0.2
# x-o--o--x:
#     xxo--o--x: 0.2
#     x-ox-o--x: 0.2
#     x-o-xo--x: 0.2
#     x-o--ox-x: 0.2
#     x-o--o-xx: 0.2
# x-o---o-x:
#     xxo---o-x: 0.2
#     x-ox--o-x: 0.2
#     x-o-x-o-x: 0.2
#     x-o--xo-x: 0.2
#     x-o---oxx: 0.2
# x-o----ox:
#     xxo----ox: 0.2
#     x-ox---ox: 0.2
#     x-o-x--ox: 0.2
#     x-o--x-ox: 0.2
#     x-o---xox: 0.2
# xx-oo----:
#     xxxoo----: 0.2
#     xx-oox---: 0.2
#     xx-oo-x--: 0.2
#     xx-oo--x-: 0.2
#     xx-oo---x: 0.2
# xx-o-o---:
#     xxxo-o---: 0.2
#     xx-oxo---: 0.2
#     xx-o-ox--: 0.2
#     xx-o-o-x-: 0.2
#     xx-o-o--x: 0.2
# xx-o--o--:
#     xxxo--o--: 0.2
#     xx-ox-o--: 0.2
#     xx-o-xo--: 0.2
#     xx-o--ox-: 0.2
#     xx-o--o-x: 0.2
# xx-o---o-:
#     xxxo---o-: 0.2
#     xx-ox--o-: 0.2
#     xx-o-x-o-: 0.2
#     xx-o--xo-: 0.2
#     xx-o---ox: 0.2
# xx-o----o:
#     xxxo----o: 0.2
#     xx-ox---o: 0.2
#     xx-o-x--o: 0.2
#     xx-o--x-o: 0.2
#     xx-o---xo: 0.2
# x-xoo----:
#     xxxoo----: 0.2
#     x-xoox---: 0.2
#     x-xoo-x--: 0.2
#     x-xoo--x-: 0.2
#     x-xoo---x: 0.2
# x-xo-o---:
#     xxxo-o---: 0.2
#     x-xoxo---: 0.2
#     x-xo-ox--: 0.2
#     x-xo-o-x-: 0.2
#     x-xo-o--x: 0.2
# x-xo--o--:
#     xxxo--o--: 0.2
#     x-xox-o--: 0.2
#     x-xo-xo--: 0.2
#     x-xo--ox-: 0.2
#     x-xo--o-x: 0.2
# x-xo---o-:
#     xxxo---o-: 0.2
#     x-xox--o-: 0.2
#     x-xo-x-o-: 0.2
#     x-xo--xo-: 0.2
#     x-xo---ox: 0.2
# x-xo----o:
#     xxxo----o: 0.2
#     x-xox---o: 0.2
#     x-xo-x--o: 0.2
#     x-xo--x-o: 0.2
#     x-xo---xo: 0.2
# x--oxo---:
#     xx-oxo---: 0.2
#     x-xoxo---: 0.2
#     x--oxox--: 0.2
#     x--oxo-x-: 0.2
#     x--oxo--x: 0.2
# x--ox-o--:
#     xx-ox-o--: 0.2
#     x-xox-o--: 0.2
#     x--oxxo--: 0.2
#     x--ox-ox-: 0.2
#     x--ox-o-x: 0.2
# x--ox--o-:
#     xx-ox--o-: 0.2
#     x-xox--o-: 0.2
#     x--oxx-o-: 0.2
#     x--ox-xo-: 0.2
#     x--ox--ox: 0.2
# x--ox---o:
#     xx-ox---o: 0.2
#     x-xox---o: 0.2
#     x--oxx--o: 0.2
#     x--ox-x-o: 0.2
#     x--ox--xo: 0.2
# x--oox---:
#     xx-oox---: 0.2
#     x-xoox---: 0.2
#     x--ooxx--: 0.2
#     x--oox-x-: 0.2
#     x--oox--x: 0.2
# x--o-xo--:
#     xx-o-xo--: 0.2
#     x-xo-xo--: 0.2
#     x--oxxo--: 0.2
#     x--o-xox-: 0.2
#     x--o-xo-x: 0.2
# x--o-x-o-:
#     xx-o-x-o-: 0.2
#     x-xo-x-o-: 0.2
#     x--oxx-o-: 0.2
#     x--o-xxo-: 0.2
#     x--o-x-ox: 0.2
# x--o-x--o:
#     xx-o-x--o: 0.2
#     x-xo-x--o: 0.2
#     x--oxx--o: 0.2
#     x--o-xx-o: 0.2
#     x--o-x-xo: 0.2
# x--oo-x--:
#     xx-oo-x--: 0.2
#     x-xoo-x--: 0.2
#     x--ooxx--: 0.2
#     x--oo-xx-: 0.2
#     x--oo-x-x: 0.2
# x--o-ox--:
#     xx-o-ox--: 0.2
#     x-xo-ox--: 0.2
#     x--oxox--: 0.2
#     x--o-oxx-: 0.2
#     x--o-ox-x: 0.2
# x--o--xo-:
#     xx-o--xo-: 0.2
#     x-xo--xo-: 0.2
#     x--ox-xo-: 0.2
#     x--o-xxo-: 0.2
#     x--o--xox: 0.2
# x--o--x-o:
#     xx-o--x-o: 0.2
#     x-xo--x-o: 0.2
#     x--ox-x-o: 0.2
#     x--o-xx-o: 0.2
#     x--o--xxo: 0.2
# x--oo--x-:
#     xx-oo--x-: 0.2
#     x-xoo--x-: 0.2
#     x--oox-x-: 0.2
#     x--oo-xx-: 0.2
#     x--oo--xx: 0.2
# x--o-o-x-:
#     xx-o-o-x-: 0.2
#     x-xo-o-x-: 0.2
#     x--oxo-x-: 0.2
#     x--o-oxx-: 0.2
#     x--o-o-xx: 0.2
# x--o--ox-:
#     xx-o--ox-: 0.2
#     x-xo--ox-: 0.2
#     x--ox-ox-: 0.2
#     x--o-xox-: 0.2
#     x--o--oxx: 0.2
# x--o---xo:
#     xx-o---xo: 0.2
#     x-xo---xo: 0.2
#     x--ox--xo: 0.2
#     x--o-x-xo: 0.2
#     x--o--xxo: 0.2
# x--oo---x:
#     xx-oo---x: 0.2
#     x-xoo---x: 0.2
#     x--oox--x: 0.2
#     x--oo-x-x: 0.2
#     x--oo--xx: 0.2
# x--o-o--x:
#     xx-o-o--x: 0.2
#     x-xo-o--x: 0.2
#     x--oxo--x: 0.2
#     x--o-ox-x: 0.2
#     x--o-o-xx: 0.2
# x--o--o-x:
#     xx-o--o-x: 0.2
#     x-xo--o-x: 0.2
#     x--ox-o-x: 0.2
#     x--o-xo-x: 0.2
#     x--o--oxx: 0.2
# x--o---ox:
#     xx-o---ox: 0.2
#     x-xo---ox: 0.2
#     x--ox--ox: 0.2
#     x--o-x-ox: 0.2
#     x--o--xox: 0.2
# xx--oo---:
#     xxx-oo---: 0.2
#     xx-xoo---: 0.2
#     xx--oox--: 0.2
#     xx--oo-x-: 0.2
#     xx--oo--x: 0.2
# xx--o-o--:
#     xxx-o-o--: 0.2
#     xx-xo-o--: 0.2
#     xx--oxo--: 0.2
#     xx--o-ox-: 0.2
#     xx--o-o-x: 0.2
# xx--o--o-:
#     xxx-o--o-: 0.2
#     xx-xo--o-: 0.2
#     xx--ox-o-: 0.2
#     xx--o-xo-: 0.2
#     xx--o--ox: 0.2
# xx--o---o:
#     xxx-o---o: 0.2
#     xx-xo---o: 0.2
#     xx--ox--o: 0.2
#     xx--o-x-o: 0.2
#     xx--o--xo: 0.2
# x-x-oo---:
#     xxx-oo---: 0.2
#     x-xxoo---: 0.2
#     x-x-oox--: 0.2
#     x-x-oo-x-: 0.2
#     x-x-oo--x: 0.2
# x-x-o-o--:
#     xxx-o-o--: 0.2
#     x-xxo-o--: 0.2
#     x-x-oxo--: 0.2
#     x-x-o-ox-: 0.2
#     x-x-o-o-x: 0.2
# x-x-o--o-:
#     xxx-o--o-: 0.2
#     x-xxo--o-: 0.2
#     x-x-ox-o-: 0.2
#     x-x-o-xo-: 0.2
#     x-x-o--ox: 0.2
# x-x-o---o:
#     xxx-o---o: 0.2
#     x-xxo---o: 0.2
#     x-x-ox--o: 0.2
#     x-x-o-x-o: 0.2
#     x-x-o--xo: 0.2
# x--xoo---:
#     xx-xoo---: 0.2
#     x-xxoo---: 0.2
#     x--xoox--: 0.2
#     x--xoo-x-: 0.2
#     x--xoo--x: 0.2
# x--xo-o--:
#     xx-xo-o--: 0.2
#     x-xxo-o--: 0.2
#     x--xoxo--: 0.2
#     x--xo-ox-: 0.2
#     x--xo-o-x: 0.2
# x--xo--o-:
#     xx-xo--o-: 0.2
#     x-xxo--o-: 0.2
#     x--xox-o-: 0.2
#     x--xo-xo-: 0.2
#     x--xo--ox: 0.2
# x--xo---o:
#     xx-xo---o: 0.2
#     x-xxo---o: 0.2
#     x--xox--o: 0.2
#     x--xo-x-o: 0.2
#     x--xo--xo: 0.2
# x---oxo--:
#     xx--oxo--: 0.2
#     x-x-oxo--: 0.2
#     x--xoxo--: 0.2
#     x---oxox-: 0.2
#     x---oxo-x: 0.2
# x---ox-o-:
#     xx--ox-o-: 0.2
#     x-x-ox-o-: 0.2
#     x--xox-o-: 0.2
#     x---oxxo-: 0.2
#     x---ox-ox: 0.2
# x---ox--o:
#     xx--ox--o: 0.2
#     x-x-ox--o: 0.2
#     x--xox--o: 0.2
#     x---oxx-o: 0.2
#     x---ox-xo: 0.2
# x---oox--:
#     xx--oox--: 0.2
#     x-x-oox--: 0.2
#     x--xoox--: 0.2
#     x---ooxx-: 0.2
#     x---oox-x: 0.2
# x---o-xo-:
#     xx--o-xo-: 0.2
#     x-x-o-xo-: 0.2
#     x--xo-xo-: 0.2
#     x---oxxo-: 0.2
#     x---o-xox: 0.2
# x---o-x-o:
#     xx--o-x-o: 0.2
#     x-x-o-x-o: 0.2
#     x--xo-x-o: 0.2
#     x---oxx-o: 0.2
#     x---o-xxo: 0.2
# x---oo-x-:
#     xx--oo-x-: 0.2
#     x-x-oo-x-: 0.2
#     x--xoo-x-: 0.2
#     x---ooxx-: 0.2
#     x---oo-xx: 0.2
# x---o-ox-:
#     xx--o-ox-: 0.2
#     x-x-o-ox-: 0.2
#     x--xo-ox-: 0.2
#     x---oxox-: 0.2
#     x---o-oxx: 0.2
# x---o--xo:
#     xx--o--xo: 0.2
#     x-x-o--xo: 0.2
#     x--xo--xo: 0.2
#     x---ox-xo: 0.2
#     x---o-xxo: 0.2
# x---oo--x:
#     xx--oo--x: 0.2
#     x-x-oo--x: 0.2
#     x--xoo--x: 0.2
#     x---oox-x: 0.2
#     x---oo-xx: 0.2
# x---o-o-x:
#     xx--o-o-x: 0.2
#     x-x-o-o-x: 0.2
#     x--xo-o-x: 0.2
#     x---oxo-x: 0.2
#     x---o-oxx: 0.2
# x---o--ox:
#     xx--o--ox: 0.2
#     x-x-o--ox: 0.2
#     x--xo--ox: 0.2
#     x---ox-ox: 0.2
#     x---o-xox: 0.2
# xx---oo--:
#     xxx--oo--: 0.2
#     xx-x-oo--: 0.2
#     xx--xoo--: 0.2
#     xx---oox-: 0.2
#     xx---oo-x: 0.2
# xx---o-o-:
#     xxx--o-o-: 0.2
#     xx-x-o-o-: 0.2
#     xx--xo-o-: 0.2
#     xx---oxo-: 0.2
#     xx---o-ox: 0.2
# xx---o--o:
#     xxx--o--o: 0.2
#     xx-x-o--o: 0.2
#     xx--xo--o: 0.2
#     xx---ox-o: 0.2
#     xx---o-xo: 0.2
# x-x--oo--:
#     xxx--oo--: 0.2
#     x-xx-oo--: 0.2
#     x-x-xoo--: 0.2
#     x-x--oox-: 0.2
#     x-x--oo-x: 0.2
# x-x--o-o-:
#     xxx--o-o-: 0.2
#     x-xx-o-o-: 0.2
#     x-x-xo-o-: 0.2
#     x-x--oxo-: 0.2
#     x-x--o-ox: 0.2
# x-x--o--o:
#     xxx--o--o: 0.2
#     x-xx-o--o: 0.2
#     x-x-xo--o: 0.2
#     x-x--ox-o: 0.2
#     x-x--o-xo: 0.2
# x--x-oo--:
#     xx-x-oo--: 0.2
#     x-xx-oo--: 0.2
#     x--xxoo--: 0.2
#     x--x-oox-: 0.2
#     x--x-oo-x: 0.2
# x--x-o-o-:
#     xx-x-o-o-: 0.2
#     x-xx-o-o-: 0.2
#     x--xxo-o-: 0.2
#     x--x-oxo-: 0.2
#     x--x-o-ox: 0.2
# x--x-o--o:
#     xx-x-o--o: 0.2
#     x-xx-o--o: 0.2
#     x--xxo--o: 0.2
#     x--x-ox-o: 0.2
#     x--x-o-xo: 0.2
# x---xoo--:
#     xx--xoo--: 0.2
#     x-x-xoo--: 0.2
#     x--xxoo--: 0.2
#     x---xoox-: 0.2
#     x---xoo-x: 0.2
# x---xo-o-:
#     xx--xo-o-: 0.2
#     x-x-xo-o-: 0.2
#     x--xxo-o-: 0.2
#     x---xoxo-: 0.2
#     x---xo-ox: 0.2
# x---xo--o:
#     xx--xo--o: 0.2
#     x-x-xo--o: 0.2
#     x--xxo--o: 0.2
#     x---xox-o: 0.2
#     x---xo-xo: 0.2
# x----oxo-:
#     xx---oxo-: 0.2
#     x-x--oxo-: 0.2
#     x--x-oxo-: 0.2
#     x---xoxo-: 0.2
#     x----oxox: 0.2
# x----ox-o:
#     xx---ox-o: 0.2
#     x-x--ox-o: 0.2
#     x--x-ox-o: 0.2
#     x---xox-o: 0.2
#     x----oxxo: 0.2
# x----oox-:
#     xx---oox-: 0.2
#     x-x--oox-: 0.2
#     x--x-oox-: 0.2
#     x---xoox-: 0.2
#     x----ooxx: 0.2
# x----o-xo:
#     xx---o-xo: 0.2
#     x-x--o-xo: 0.2
#     x--x-o-xo: 0.2
#     x---xo-xo: 0.2
#     x----oxxo: 0.2
# x----oo-x:
#     xx---oo-x: 0.2
#     x-x--oo-x: 0.2
#     x--x-oo-x: 0.2
#     x---xoo-x: 0.2
#     x----ooxx: 0.2
# x----o-ox:
#     xx---o-ox: 0.2
#     x-x--o-ox: 0.2
#     x--x-o-ox: 0.2
#     x---xo-ox: 0.2
#     x----oxox: 0.2
# xx----oo-:
#     xxx---oo-: 0.2
#     xx-x--oo-: 0.2
#     xx--x-oo-: 0.2
#     xx---xoo-: 0.2
#     xx----oox: 0.2
# xx----o-o:
#     xxx---o-o: 0.2
#     xx-x--o-o: 0.2
#     xx--x-o-o: 0.2
#     xx---xo-o: 0.2
#     xx----oxo: 0.2
# x-x---oo-:
#     xxx---oo-: 0.2
#     x-xx--oo-: 0.2
#     x-x-x-oo-: 0.2
#     x-x--xoo-: 0.2
#     x-x---oox: 0.2
# x-x---o-o:
#     xxx---o-o: 0.2
#     x-xx--o-o: 0.2
#     x-x-x-o-o: 0.2
#     x-x--xo-o: 0.2
#     x-x---oxo: 0.2
# x--x--oo-:
#     xx-x--oo-: 0.2
#     x-xx--oo-: 0.2
#     x--xx-oo-: 0.2
#     x--x-xoo-: 0.2
#     x--x--oox: 0.2
# x--x--o-o:
#     xx-x--o-o: 0.2
#     x-xx--o-o: 0.2
#     x--xx-o-o: 0.2
#     x--x-xo-o: 0.2
#     x--x--oxo: 0.2
# x---x-oo-:
#     xx--x-oo-: 0.2
#     x-x-x-oo-: 0.2
#     x--xx-oo-: 0.2
#     x---xxoo-: 0.2
#     x---x-oox: 0.2
# x---x-o-o:
#     xx--x-o-o: 0.2
#     x-x-x-o-o: 0.2
#     x--xx-o-o: 0.2
#     x---xxo-o: 0.2
#     x---x-oxo: 0.2
# x----xoo-:
#     xx---xoo-: 0.2
#     x-x--xoo-: 0.2
#     x--x-xoo-: 0.2
#     x---xxoo-: 0.2
#     x----xoox: 0.2
# x----xo-o:
#     xx---xo-o: 0.2
#     x-x--xo-o: 0.2
#     x--x-xo-o: 0.2
#     x---xxo-o: 0.2
#     x----xoxo: 0.2
# x-----oxo:
#     xx----oxo: 0.2
#     x-x---oxo: 0.2
#     x--x--oxo: 0.2
#     x---x-oxo: 0.2
#     x----xoxo: 0.2
# x-----oox:
#     xx----oox: 0.2
#     x-x---oox: 0.2
#     x--x--oox: 0.2
#     x---x-oox: 0.2
#     x----xoox: 0.2
# xx-----oo:
#     xxx----oo: 0.2
#     xx-x---oo: 0.2
#     xx--x--oo: 0.2
#     xx---x-oo: 0.2
#     xx----xoo: 0.2
# x-x----oo:
#     xxx----oo: 0.2
#     x-xx---oo: 0.2
#     x-x-x--oo: 0.2
#     x-x--x-oo: 0.2
#     x-x---xoo: 0.2
# x--x---oo:
#     xx-x---oo: 0.2
#     x-xx---oo: 0.2
#     x--xx--oo: 0.2
#     x--x-x-oo: 0.2
#     x--x--xoo: 0.2
# x---x--oo:
#     xx--x--oo: 0.2
#     x-x-x--oo: 0.2
#     x--xx--oo: 0.2
#     x---xx-oo: 0.2
#     x---x-xoo: 0.2
# x----x-oo:
#     xx---x-oo: 0.2
#     x-x--x-oo: 0.2
#     x--x-x-oo: 0.2
#     x---xx-oo: 0.2
#     x----xxoo: 0.2
# x-----xoo:
#     xx----xoo: 0.2
#     x-x---xoo: 0.2
#     x--x--xoo: 0.2
#     x---x-xoo: 0.2
#     x----xxoo: 0.2
# oxxo-----:
#     oxxox----: 0.2
#     oxxo-x---: 0.2
#     oxxo--x--: 0.2
#     oxxo---x-: 0.2
#     oxxo----x: 0.2
# oxx-o----:
#     oxxxo----: 0.2
#     oxx-ox---: 0.2
#     oxx-o-x--: 0.2
#     oxx-o--x-: 0.2
#     oxx-o---x: 0.2
# oxx--o---:
#     oxxx-o---: 0.2
#     oxx-xo---: 0.2
#     oxx--ox--: 0.2
#     oxx--o-x-: 0.2
#     oxx--o--x: 0.2
# oxx---o--:
#     oxxx--o--: 0.2
#     oxx-x-o--: 0.2
#     oxx--xo--: 0.2
#     oxx---ox-: 0.2
#     oxx---o-x: 0.2
# oxx----o-:
#     oxxx---o-: 0.2
#     oxx-x--o-: 0.2
#     oxx--x-o-: 0.2
#     oxx---xo-: 0.2
#     oxx----ox: 0.2
# oxx-----o:
#     oxxx----o: 0.2
#     oxx-x---o: 0.2
#     oxx--x--o: 0.2
#     oxx---x-o: 0.2
#     oxx----xo: 0.2
# oxox-----:
#     oxoxx----: 0.2
#     oxox-x---: 0.2
#     oxox--x--: 0.2
#     oxox---x-: 0.2
#     oxox----x: 0.2
# ox-xo----:
#     oxxxo----: 0.2
#     ox-xox---: 0.2
#     ox-xo-x--: 0.2
#     ox-xo--x-: 0.2
#     ox-xo---x: 0.2
# ox-x-o---:
#     oxxx-o---: 0.2
#     ox-xxo---: 0.2
#     ox-x-ox--: 0.2
#     ox-x-o-x-: 0.2
#     ox-x-o--x: 0.2
# ox-x--o--:
#     oxxx--o--: 0.2
#     ox-xx-o--: 0.2
#     ox-x-xo--: 0.2
#     ox-x--ox-: 0.2
#     ox-x--o-x: 0.2
# ox-x---o-:
#     oxxx---o-: 0.2
#     ox-xx--o-: 0.2
#     ox-x-x-o-: 0.2
#     ox-x--xo-: 0.2
#     ox-x---ox: 0.2
# ox-x----o:
#     oxxx----o: 0.2
#     ox-xx---o: 0.2
#     ox-x-x--o: 0.2
#     ox-x--x-o: 0.2
#     ox-x---xo: 0.2
# oxo-x----:
#     oxoxx----: 0.2
#     oxo-xx---: 0.2
#     oxo-x-x--: 0.2
#     oxo-x--x-: 0.2
#     oxo-x---x: 0.2
# ox-ox----:
#     oxxox----: 0.2
#     ox-oxx---: 0.2
#     ox-ox-x--: 0.2
#     ox-ox--x-: 0.2
#     ox-ox---x: 0.2
# ox--xo---:
#     oxx-xo---: 0.2
#     ox-xxo---: 0.2
#     ox--xox--: 0.2
#     ox--xo-x-: 0.2
#     ox--xo--x: 0.2
# ox--x-o--:
#     oxx-x-o--: 0.2
#     ox-xx-o--: 0.2
#     ox--xxo--: 0.2
#     ox--x-ox-: 0.2
#     ox--x-o-x: 0.2
# ox--x--o-:
#     oxx-x--o-: 0.2
#     ox-xx--o-: 0.2
#     ox--xx-o-: 0.2
#     ox--x-xo-: 0.2
#     ox--x--ox: 0.2
# ox--x---o:
#     oxx-x---o: 0.2
#     ox-xx---o: 0.2
#     ox--xx--o: 0.2
#     ox--x-x-o: 0.2
#     ox--x--xo: 0.2
# oxo--x---:
#     oxox-x---: 0.2
#     oxo-xx---: 0.2
#     oxo--xx--: 0.2
#     oxo--x-x-: 0.2
#     oxo--x--x: 0.2
# ox-o-x---:
#     oxxo-x---: 0.2
#     ox-oxx---: 0.2
#     ox-o-xx--: 0.2
#     ox-o-x-x-: 0.2
#     ox-o-x--x: 0.2
# ox--ox---:
#     oxx-ox---: 0.2
#     ox-xox---: 0.2
#     ox--oxx--: 0.2
#     ox--ox-x-: 0.2
#     ox--ox--x: 0.2
# ox---xo--:
#     oxx--xo--: 0.2
#     ox-x-xo--: 0.2
#     ox--xxo--: 0.2
#     ox---xox-: 0.2
#     ox---xo-x: 0.2
# ox---x-o-:
#     oxx--x-o-: 0.2
#     ox-x-x-o-: 0.2
#     ox--xx-o-: 0.2
#     ox---xxo-: 0.2
#     ox---x-ox: 0.2
# ox---x--o:
#     oxx--x--o: 0.2
#     ox-x-x--o: 0.2
#     ox--xx--o: 0.2
#     ox---xx-o: 0.2
#     ox---x-xo: 0.2
# oxo---x--:
#     oxox--x--: 0.2
#     oxo-x-x--: 0.2
#     oxo--xx--: 0.2
#     oxo---xx-: 0.2
#     oxo---x-x: 0.2
# ox-o--x--:
#     oxxo--x--: 0.2
#     ox-ox-x--: 0.2
#     ox-o-xx--: 0.2
#     ox-o--xx-: 0.2
#     ox-o--x-x: 0.2
# ox--o-x--:
#     oxx-o-x--: 0.2
#     ox-xo-x--: 0.2
#     ox--oxx--: 0.2
#     ox--o-xx-: 0.2
#     ox--o-x-x: 0.2
# ox---ox--:
#     oxx--ox--: 0.2
#     ox-x-ox--: 0.2
#     ox--xox--: 0.2
#     ox---oxx-: 0.2
#     ox---ox-x: 0.2
# ox----xo-:
#     oxx---xo-: 0.2
#     ox-x--xo-: 0.2
#     ox--x-xo-: 0.2
#     ox---xxo-: 0.2
#     ox----xox: 0.2
# ox----x-o:
#     oxx---x-o: 0.2
#     ox-x--x-o: 0.2
#     ox--x-x-o: 0.2
#     ox---xx-o: 0.2
#     ox----xxo: 0.2
# oxo----x-:
#     oxox---x-: 0.2
#     oxo-x--x-: 0.2
#     oxo--x-x-: 0.2
#     oxo---xx-: 0.2
#     oxo----xx: 0.2
# ox-o---x-:
#     oxxo---x-: 0.2
#     ox-ox--x-: 0.2
#     ox-o-x-x-: 0.2
#     ox-o--xx-: 0.2
#     ox-o---xx: 0.2
# ox--o--x-:
#     oxx-o--x-: 0.2
#     ox-xo--x-: 0.2
#     ox--ox-x-: 0.2
#     ox--o-xx-: 0.2
#     ox--o--xx: 0.2
# ox---o-x-:
#     oxx--o-x-: 0.2
#     ox-x-o-x-: 0.2
#     ox--xo-x-: 0.2
#     ox---oxx-: 0.2
#     ox---o-xx: 0.2
# ox----ox-:
#     oxx---ox-: 0.2
#     ox-x--ox-: 0.2
#     ox--x-ox-: 0.2
#     ox---xox-: 0.2
#     ox----oxx: 0.2
# ox-----xo:
#     oxx----xo: 0.2
#     ox-x---xo: 0.2
#     ox--x--xo: 0.2
#     ox---x-xo: 0.2
#     ox----xxo: 0.2
# oxo-----x:
#     oxox----x: 0.2
#     oxo-x---x: 0.2
#     oxo--x--x: 0.2
#     oxo---x-x: 0.2
#     oxo----xx: 0.2
# ox-o----x:
#     oxxo----x: 0.2
#     ox-ox---x: 0.2
#     ox-o-x--x: 0.2
#     ox-o--x-x: 0.2
#     ox-o---xx: 0.2
# ox--o---x:
#     oxx-o---x: 0.2
#     ox-xo---x: 0.2
#     ox--ox--x: 0.2
#     ox--o-x-x: 0.2
#     ox--o--xx: 0.2
# ox---o--x:
#     oxx--o--x: 0.2
#     ox-x-o--x: 0.2
#     ox--xo--x: 0.2
#     ox---ox-x: 0.2
#     ox---o-xx: 0.2
# ox----o-x:
#     oxx---o-x: 0.2
#     ox-x--o-x: 0.2
#     ox--x-o-x: 0.2
#     ox---xo-x: 0.2
#     ox----oxx: 0.2
# ox-----ox:
#     oxx----ox: 0.2
#     ox-x---ox: 0.2
#     ox--x--ox: 0.2
#     ox---x-ox: 0.2
#     ox----xox: 0.2
# -xoxo----:
#     xxoxo----: 0.2
#     -xoxox---: 0.2
#     -xoxo-x--: 0.2
#     -xoxo--x-: 0.2
#     -xoxo---x: 0.2
# -xox-o---:
#     xxox-o---: 0.2
#     -xoxxo---: 0.2
#     -xox-ox--: 0.2
#     -xox-o-x-: 0.2
#     -xox-o--x: 0.2
# -xox--o--:
#     xxox--o--: 0.2
#     -xoxx-o--: 0.2
#     -xox-xo--: 0.2
#     -xox--ox-: 0.2
#     -xox--o-x: 0.2
# -xox---o-:
#     xxox---o-: 0.2
#     -xoxx--o-: 0.2
#     -xox-x-o-: 0.2
#     -xox--xo-: 0.2
#     -xox---ox: 0.2
# -xox----o:
#     xxox----o: 0.2
#     -xoxx---o: 0.2
#     -xox-x--o: 0.2
#     -xox--x-o: 0.2
#     -xox---xo: 0.2
# -xoox----:
#     xxoox----: 0.2
#     -xooxx---: 0.2
#     -xoox-x--: 0.2
#     -xoox--x-: 0.2
#     -xoox---x: 0.2
# -xo-xo---:
#     xxo-xo---: 0.2
#     -xoxxo---: 0.2
#     -xo-xox--: 0.2
#     -xo-xo-x-: 0.2
#     -xo-xo--x: 0.2
# -xo-x-o--:
#     xxo-x-o--: 0.2
#     -xoxx-o--: 0.2
#     -xo-xxo--: 0.2
#     -xo-x-ox-: 0.2
#     -xo-x-o-x: 0.2
# -xo-x--o-:
#     xxo-x--o-: 0.2
#     -xoxx--o-: 0.2
#     -xo-xx-o-: 0.2
#     -xo-x-xo-: 0.2
#     -xo-x--ox: 0.2
# -xo-x---o:
#     xxo-x---o: 0.2
#     -xoxx---o: 0.2
#     -xo-xx--o: 0.2
#     -xo-x-x-o: 0.2
#     -xo-x--xo: 0.2
# -xoo-x---:
#     xxoo-x---: 0.2
#     -xooxx---: 0.2
#     -xoo-xx--: 0.2
#     -xoo-x-x-: 0.2
#     -xoo-x--x: 0.2
# -xo-ox---:
#     xxo-ox---: 0.2
#     -xoxox---: 0.2
#     -xo-oxx--: 0.2
#     -xo-ox-x-: 0.2
#     -xo-ox--x: 0.2
# -xo--xo--:
#     xxo--xo--: 0.2
#     -xox-xo--: 0.2
#     -xo-xxo--: 0.2
#     -xo--xox-: 0.2
#     -xo--xo-x: 0.2
# -xo--x-o-:
#     xxo--x-o-: 0.2
#     -xox-x-o-: 0.2
#     -xo-xx-o-: 0.2
#     -xo--xxo-: 0.2
#     -xo--x-ox: 0.2
# -xo--x--o:
#     xxo--x--o: 0.2
#     -xox-x--o: 0.2
#     -xo-xx--o: 0.2
#     -xo--xx-o: 0.2
#     -xo--x-xo: 0.2
# -xoo--x--:
#     xxoo--x--: 0.2
#     -xoox-x--: 0.2
#     -xoo-xx--: 0.2
#     -xoo--xx-: 0.2
#     -xoo--x-x: 0.2
# -xo-o-x--:
#     xxo-o-x--: 0.2
#     -xoxo-x--: 0.2
#     -xo-oxx--: 0.2
#     -xo-o-xx-: 0.2
#     -xo-o-x-x: 0.2
# -xo--ox--:
#     xxo--ox--: 0.2
#     -xox-ox--: 0.2
#     -xo-xox--: 0.2
#     -xo--oxx-: 0.2
#     -xo--ox-x: 0.2
# -xo---xo-:
#     xxo---xo-: 0.2
#     -xox--xo-: 0.2
#     -xo-x-xo-: 0.2
#     -xo--xxo-: 0.2
#     -xo---xox: 0.2
# -xo---x-o:
#     xxo---x-o: 0.2
#     -xox--x-o: 0.2
#     -xo-x-x-o: 0.2
#     -xo--xx-o: 0.2
#     -xo---xxo: 0.2
# -xoo---x-:
#     xxoo---x-: 0.2
#     -xoox--x-: 0.2
#     -xoo-x-x-: 0.2
#     -xoo--xx-: 0.2
#     -xoo---xx: 0.2
# -xo-o--x-:
#     xxo-o--x-: 0.2
#     -xoxo--x-: 0.2
#     -xo-ox-x-: 0.2
#     -xo-o-xx-: 0.2
#     -xo-o--xx: 0.2
# -xo--o-x-:
#     xxo--o-x-: 0.2
#     -xox-o-x-: 0.2
#     -xo-xo-x-: 0.2
#     -xo--oxx-: 0.2
#     -xo--o-xx: 0.2
# -xo---ox-:
#     xxo---ox-: 0.2
#     -xox--ox-: 0.2
#     -xo-x-ox-: 0.2
#     -xo--xox-: 0.2
#     -xo---oxx: 0.2
# -xo----xo:
#     xxo----xo: 0.2
#     -xox---xo: 0.2
#     -xo-x--xo: 0.2
#     -xo--x-xo: 0.2
#     -xo---xxo: 0.2
# -xoo----x:
#     xxoo----x: 0.2
#     -xoox---x: 0.2
#     -xoo-x--x: 0.2
#     -xoo--x-x: 0.2
#     -xoo---xx: 0.2
# -xo-o---x:
#     xxo-o---x: 0.15000000000000002
#     -xoxo---x: 0.21250000000000002
#     -xo-ox--x: 0.21250000000000002
#     -xo-o-x-x: 0.21250000000000002
#     -xo-o--xx: 0.21250000000000002
# -xo--o--x:
#     xxo--o--x: 0.2
#     -xox-o--x: 0.2
#     -xo-xo--x: 0.2
#     -xo--ox-x: 0.2
#     -xo--o-xx: 0.2
# -xo---o-x:
#     xxo---o-x: 0.2
#     -xox--o-x: 0.2
#     -xo-x-o-x: 0.2
#     -xo--xo-x: 0.2
#     -xo---oxx: 0.2
# -xo----ox:
#     xxo----ox: 0.2
#     -xox---ox: 0.2
#     -xo-x--ox: 0.2
#     -xo--x-ox: 0.2
#     -xo---xox: 0.2
# -xxoo----:
#     xxxoo----: 0.2
#     -xxoox---: 0.2
#     -xxoo-x--: 0.2
#     -xxoo--x-: 0.2
#     -xxoo---x: 0.2
# -xxo-o---:
#     xxxo-o---: 0.2
#     -xxoxo---: 0.2
#     -xxo-ox--: 0.2
#     -xxo-o-x-: 0.2
#     -xxo-o--x: 0.2
# -xxo--o--:
#     xxxo--o--: 0.2
#     -xxox-o--: 0.2
#     -xxo-xo--: 0.2
#     -xxo--ox-: 0.2
#     -xxo--o-x: 0.2
# -xxo---o-:
#     xxxo---o-: 0.2
#     -xxox--o-: 0.2
#     -xxo-x-o-: 0.2
#     -xxo--xo-: 0.2
#     -xxo---ox: 0.2
# -xxo----o:
#     xxxo----o: 0.2
#     -xxox---o: 0.2
#     -xxo-x--o: 0.2
#     -xxo--x-o: 0.2
#     -xxo---xo: 0.2
# -x-oxo---:
#     xx-oxo---: 0.2
#     -xxoxo---: 0.2
#     -x-oxox--: 0.2
#     -x-oxo-x-: 0.2
#     -x-oxo--x: 0.2
# -x-ox-o--:
#     xx-ox-o--: 0.2
#     -xxox-o--: 0.2
#     -x-oxxo--: 0.2
#     -x-ox-ox-: 0.2
#     -x-ox-o-x: 0.2
# -x-ox--o-:
#     xx-ox--o-: 0.2
#     -xxox--o-: 0.2
#     -x-oxx-o-: 0.2
#     -x-ox-xo-: 0.2
#     -x-ox--ox: 0.2
# -x-ox---o:
#     xx-ox---o: 0.2
#     -xxox---o: 0.2
#     -x-oxx--o: 0.2
#     -x-ox-x-o: 0.2
#     -x-ox--xo: 0.2
# -x-oox---:
#     xx-oox---: 0.2
#     -xxoox---: 0.2
#     -x-ooxx--: 0.2
#     -x-oox-x-: 0.2
#     -x-oox--x: 0.2
# -x-o-xo--:
#     xx-o-xo--: 0.2
#     -xxo-xo--: 0.2
#     -x-oxxo--: 0.2
#     -x-o-xox-: 0.2
#     -x-o-xo-x: 0.2
# -x-o-x-o-:
#     xx-o-x-o-: 0.2
#     -xxo-x-o-: 0.2
#     -x-oxx-o-: 0.2
#     -x-o-xxo-: 0.2
#     -x-o-x-ox: 0.2
# -x-o-x--o:
#     xx-o-x--o: 0.2
#     -xxo-x--o: 0.2
#     -x-oxx--o: 0.2
#     -x-o-xx-o: 0.2
#     -x-o-x-xo: 0.2
# -x-oo-x--:
#     xx-oo-x--: 0.2
#     -xxoo-x--: 0.2
#     -x-ooxx--: 0.2
#     -x-oo-xx-: 0.2
#     -x-oo-x-x: 0.2
# -x-o-ox--:
#     xx-o-ox--: 0.2
#     -xxo-ox--: 0.2
#     -x-oxox--: 0.2
#     -x-o-oxx-: 0.2
#     -x-o-ox-x: 0.2
# -x-o--xo-:
#     xx-o--xo-: 0.2
#     -xxo--xo-: 0.2
#     -x-ox-xo-: 0.2
#     -x-o-xxo-: 0.2
#     -x-o--xox: 0.2
# -x-o--x-o:
#     xx-o--x-o: 0.2
#     -xxo--x-o: 0.2
#     -x-ox-x-o: 0.2
#     -x-o-xx-o: 0.2
#     -x-o--xxo: 0.2
# -x-oo--x-:
#     xx-oo--x-: 0.2
#     -xxoo--x-: 0.2
#     -x-oox-x-: 0.2
#     -x-oo-xx-: 0.2
#     -x-oo--xx: 0.2
# -x-o-o-x-:
#     xx-o-o-x-: 0.2
#     -xxo-o-x-: 0.2
#     -x-oxo-x-: 0.2
#     -x-o-oxx-: 0.2
#     -x-o-o-xx: 0.2
# -x-o--ox-:
#     xx-o--ox-: 0.2
#     -xxo--ox-: 0.2
#     -x-ox-ox-: 0.2
#     -x-o-xox-: 0.2
#     -x-o--oxx: 0.2
# -x-o---xo:
#     xx-o---xo: 0.2
#     -xxo---xo: 0.2
#     -x-ox--xo: 0.2
#     -x-o-x-xo: 0.2
#     -x-o--xxo: 0.2
# -x-oo---x:
#     xx-oo---x: 0.2
#     -xxoo---x: 0.2
#     -x-oox--x: 0.2
#     -x-oo-x-x: 0.2
#     -x-oo--xx: 0.2
# -x-o-o--x:
#     xx-o-o--x: 0.2
#     -xxo-o--x: 0.2
#     -x-oxo--x: 0.2
#     -x-o-ox-x: 0.2
#     -x-o-o-xx: 0.2
# -x-o--o-x:
#     xx-o--o-x: 0.2
#     -xxo--o-x: 0.2
#     -x-ox-o-x: 0.2
#     -x-o-xo-x: 0.2
#     -x-o--oxx: 0.2
# -x-o---ox:
#     xx-o---ox: 0.2
#     -xxo---ox: 0.2
#     -x-ox--ox: 0.2
#     -x-o-x-ox: 0.2
#     -x-o--xox: 0.2
# -xx-oo---:
#     xxx-oo---: 0.2
#     -xxxoo---: 0.2
#     -xx-oox--: 0.2
#     -xx-oo-x-: 0.2
#     -xx-oo--x: 0.2
# -xx-o-o--:
#     xxx-o-o--: 0.2
#     -xxxo-o--: 0.2
#     -xx-oxo--: 0.2
#     -xx-o-ox-: 0.2
#     -xx-o-o-x: 0.2
# -xx-o--o-:
#     xxx-o--o-: 0.2
#     -xxxo--o-: 0.2
#     -xx-ox-o-: 0.2
#     -xx-o-xo-: 0.2
#     -xx-o--ox: 0.2
# -xx-o---o:
#     xxx-o---o: 0.2
#     -xxxo---o: 0.2
#     -xx-ox--o: 0.2
#     -xx-o-x-o: 0.2
#     -xx-o--xo: 0.2
# -x-xoo---:
#     xx-xoo---: 0.2
#     -xxxoo---: 0.2
#     -x-xoox--: 0.2
#     -x-xoo-x-: 0.2
#     -x-xoo--x: 0.2
# -x-xo-o--:
#     xx-xo-o--: 0.2
#     -xxxo-o--: 0.2
#     -x-xoxo--: 0.2
#     -x-xo-ox-: 0.2
#     -x-xo-o-x: 0.2
# -x-xo--o-:
#     xx-xo--o-: 0.2
#     -xxxo--o-: 0.2
#     -x-xox-o-: 0.2
#     -x-xo-xo-: 0.2
#     -x-xo--ox: 0.2
# -x-xo---o:
#     xx-xo---o: 0.2
#     -xxxo---o: 0.2
#     -x-xox--o: 0.2
#     -x-xo-x-o: 0.2
#     -x-xo--xo: 0.2
# -x--oxo--:
#     xx--oxo--: 0.2
#     -xx-oxo--: 0.2
#     -x-xoxo--: 0.2
#     -x--oxox-: 0.2
#     -x--oxo-x: 0.2
# -x--ox-o-:
#     xx--ox-o-: 0.2
#     -xx-ox-o-: 0.2
#     -x-xox-o-: 0.2
#     -x--oxxo-: 0.2
#     -x--ox-ox: 0.2
# -x--ox--o:
#     xx--ox--o: 0.2
#     -xx-ox--o: 0.2
#     -x-xox--o: 0.2
#     -x--oxx-o: 0.2
#     -x--ox-xo: 0.2
# -x--oox--:
#     xx--oox--: 0.2
#     -xx-oox--: 0.2
#     -x-xoox--: 0.2
#     -x--ooxx-: 0.2
#     -x--oox-x: 0.2
# -x--o-xo-:
#     xx--o-xo-: 0.2
#     -xx-o-xo-: 0.2
#     -x-xo-xo-: 0.2
#     -x--oxxo-: 0.2
#     -x--o-xox: 0.2
# -x--o-x-o:
#     xx--o-x-o: 0.2
#     -xx-o-x-o: 0.2
#     -x-xo-x-o: 0.2
#     -x--oxx-o: 0.2
#     -x--o-xxo: 0.2
# -x--oo-x-:
#     xx--oo-x-: 0.2
#     -xx-oo-x-: 0.2
#     -x-xoo-x-: 0.2
#     -x--ooxx-: 0.2
#     -x--oo-xx: 0.2
# -x--o-ox-:
#     xx--o-ox-: 0.2
#     -xx-o-ox-: 0.2
#     -x-xo-ox-: 0.2
#     -x--oxox-: 0.2
#     -x--o-oxx: 0.2
# -x--o--xo:
#     xx--o--xo: 0.2
#     -xx-o--xo: 0.2
#     -x-xo--xo: 0.2
#     -x--ox-xo: 0.2
#     -x--o-xxo: 0.2
# -x--oo--x:
#     xx--oo--x: 0.2
#     -xx-oo--x: 0.2
#     -x-xoo--x: 0.2
#     -x--oox-x: 0.2
#     -x--oo-xx: 0.2
# -x--o-o-x:
#     xx--o-o-x: 0.2
#     -xx-o-o-x: 0.2
#     -x-xo-o-x: 0.2
#     -x--oxo-x: 0.2
#     -x--o-oxx: 0.2
# -x--o--ox:
#     xx--o--ox: 0.2
#     -xx-o--ox: 0.2
#     -x-xo--ox: 0.2
#     -x--ox-ox: 0.2
#     -x--o-xox: 0.2
# -xx--oo--:
#     xxx--oo--: 0.2
#     -xxx-oo--: 0.2
#     -xx-xoo--: 0.2
#     -xx--oox-: 0.2
#     -xx--oo-x: 0.2
# -xx--o-o-:
#     xxx--o-o-: 0.2
#     -xxx-o-o-: 0.2
#     -xx-xo-o-: 0.2
#     -xx--oxo-: 0.2
#     -xx--o-ox: 0.2
# -xx--o--o:
#     xxx--o--o: 0.2
#     -xxx-o--o: 0.2
#     -xx-xo--o: 0.2
#     -xx--ox-o: 0.2
#     -xx--o-xo: 0.2
# -x-x-oo--:
#     xx-x-oo--: 0.2
#     -xxx-oo--: 0.2
#     -x-xxoo--: 0.2
#     -x-x-oox-: 0.2
#     -x-x-oo-x: 0.2
# -x-x-o-o-:
#     xx-x-o-o-: 0.2
#     -xxx-o-o-: 0.2
#     -x-xxo-o-: 0.2
#     -x-x-oxo-: 0.2
#     -x-x-o-ox: 0.2
# -x-x-o--o:
#     xx-x-o--o: 0.2
#     -xxx-o--o: 0.2
#     -x-xxo--o: 0.2
#     -x-x-ox-o: 0.2
#     -x-x-o-xo: 0.2
# -x--xoo--:
#     xx--xoo--: 0.2
#     -xx-xoo--: 0.2
#     -x-xxoo--: 0.2
#     -x--xoox-: 0.2
#     -x--xoo-x: 0.2
# -x--xo-o-:
#     xx--xo-o-: 0.2
#     -xx-xo-o-: 0.2
#     -x-xxo-o-: 0.2
#     -x--xoxo-: 0.2
#     -x--xo-ox: 0.2
# -x--xo--o:
#     xx--xo--o: 0.2
#     -xx-xo--o: 0.2
#     -x-xxo--o: 0.2
#     -x--xox-o: 0.2
#     -x--xo-xo: 0.2
# -x---oxo-:
#     xx---oxo-: 0.2
#     -xx--oxo-: 0.2
#     -x-x-oxo-: 0.2
#     -x--xoxo-: 0.2
#     -x---oxox: 0.2
# -x---ox-o:
#     xx---ox-o: 0.2
#     -xx--ox-o: 0.2
#     -x-x-ox-o: 0.2
#     -x--xox-o: 0.2
#     -x---oxxo: 0.2
# -x---oox-:
#     xx---oox-: 0.2
#     -xx--oox-: 0.2
#     -x-x-oox-: 0.2
#     -x--xoox-: 0.2
#     -x---ooxx: 0.2
# -x---o-xo:
#     xx---o-xo: 0.2
#     -xx--o-xo: 0.2
#     -x-x-o-xo: 0.2
#     -x--xo-xo: 0.2
#     -x---oxxo: 0.2
# -x---oo-x:
#     xx---oo-x: 0.2
#     -xx--oo-x: 0.2
#     -x-x-oo-x: 0.2
#     -x--xoo-x: 0.2
#     -x---ooxx: 0.2
# -x---o-ox:
#     xx---o-ox: 0.2
#     -xx--o-ox: 0.2
#     -x-x-o-ox: 0.2
#     -x--xo-ox: 0.2
#     -x---oxox: 0.2
# -xx---oo-:
#     xxx---oo-: 0.2
#     -xxx--oo-: 0.2
#     -xx-x-oo-: 0.2
#     -xx--xoo-: 0.2
#     -xx---oox: 0.2
# -xx---o-o:
#     xxx---o-o: 0.2
#     -xxx--o-o: 0.2
#     -xx-x-o-o: 0.2
#     -xx--xo-o: 0.2
#     -xx---oxo: 0.2
# -x-x--oo-:
#     xx-x--oo-: 0.2
#     -xxx--oo-: 0.2
#     -x-xx-oo-: 0.2
#     -x-x-xoo-: 0.2
#     -x-x--oox: 0.2
# -x-x--o-o:
#     xx-x--o-o: 0.2
#     -xxx--o-o: 0.2
#     -x-xx-o-o: 0.2
#     -x-x-xo-o: 0.2
#     -x-x--oxo: 0.2
# -x--x-oo-:
#     xx--x-oo-: 0.2
#     -xx-x-oo-: 0.2
#     -x-xx-oo-: 0.2
#     -x--xxoo-: 0.2
#     -x--x-oox: 0.2
# -x--x-o-o:
#     xx--x-o-o: 0.2
#     -xx-x-o-o: 0.2
#     -x-xx-o-o: 0.2
#     -x--xxo-o: 0.2
#     -x--x-oxo: 0.2
# -x---xoo-:
#     xx---xoo-: 0.2
#     -xx--xoo-: 0.2
#     -x-x-xoo-: 0.2
#     -x--xxoo-: 0.2
#     -x---xoox: 0.2
# -x---xo-o:
#     xx---xo-o: 0.2
#     -xx--xo-o: 0.2
#     -x-x-xo-o: 0.2
#     -x--xxo-o: 0.2
#     -x---xoxo: 0.2
# -x----oxo:
#     xx----oxo: 0.2
#     -xx---oxo: 0.2
#     -x-x--oxo: 0.2
#     -x--x-oxo: 0.2
#     -x---xoxo: 0.2
# -x----oox:
#     xx----oox: 0.2
#     -xx---oox: 0.2
#     -x-x--oox: 0.2
#     -x--x-oox: 0.2
#     -x---xoox: 0.2
# -xx----oo:
#     xxx----oo: 0.2
#     -xxx---oo: 0.2
#     -xx-x--oo: 0.2
#     -xx--x-oo: 0.2
#     -xx---xoo: 0.2
# -x-x---oo:
#     xx-x---oo: 0.2
#     -xxx---oo: 0.2
#     -x-xx--oo: 0.2
#     -x-x-x-oo: 0.2
#     -x-x--xoo: 0.2
# -x--x--oo:
#     xx--x--oo: 0.2
#     -xx-x--oo: 0.2
#     -x-xx--oo: 0.2
#     -x--xx-oo: 0.2
#     -x--x-xoo: 0.2
# -x---x-oo:
#     xx---x-oo: 0.2
#     -xx--x-oo: 0.2
#     -x-x-x-oo: 0.2
#     -x--xx-oo: 0.2
#     -x---xxoo: 0.2
# -x----xoo:
#     xx----xoo: 0.2
#     -xx---xoo: 0.2
#     -x-x--xoo: 0.2
#     -x--x-xoo: 0.2
#     -x---xxoo: 0.2
# oox-x----:
#     ooxxx----: 0.2
#     oox-xx---: 0.2
#     oox-x-x--: 0.2
#     oox-x--x-: 0.2
#     oox-x---x: 0.2
# o-xox----:
#     oxxox----: 0.2
#     o-xoxx---: 0.2
#     o-xox-x--: 0.2
#     o-xox--x-: 0.2
#     o-xox---x: 0.2
# o-x-xo---:
#     oxx-xo---: 0.2
#     o-xxxo---: 0.2
#     o-x-xox--: 0.2
#     o-x-xo-x-: 0.2
#     o-x-xo--x: 0.2
# o-x-x-o--:
#     oxx-x-o--: 0.2
#     o-xxx-o--: 0.2
#     o-x-xxo--: 0.2
#     o-x-x-ox-: 0.2
#     o-x-x-o-x: 0.2
# o-x-x--o-:
#     oxx-x--o-: 0.2
#     o-xxx--o-: 0.2
#     o-x-xx-o-: 0.2
#     o-x-x-xo-: 0.2
#     o-x-x--ox: 0.2
# o-x-x---o:
#     oxx-x---o: 0.2
#     o-xxx---o: 0.2
#     o-x-xx--o: 0.2
#     o-x-x-x-o: 0.2
#     o-x-x--xo: 0.2
# oo-xx----:
#     ooxxx----: 0.2
#     oo-xxx---: 0.2
#     oo-xx-x--: 0.2
#     oo-xx--x-: 0.2
#     oo-xx---x: 0.2
# o-oxx----:
#     oxoxx----: 0.2
#     o-oxxx---: 0.2
#     o-oxx-x--: 0.2
#     o-oxx--x-: 0.2
#     o-oxx---x: 0.2
# o--xxo---:
#     ox-xxo---: 0.2
#     o-xxxo---: 0.2
#     o--xxox--: 0.2
#     o--xxo-x-: 0.2
#     o--xxo--x: 0.2
# o--xx-o--:
#     ox-xx-o--: 0.2
#     o-xxx-o--: 0.2
#     o--xxxo--: 0.2
#     o--xx-ox-: 0.2
#     o--xx-o-x: 0.2
# o--xx--o-:
#     ox-xx--o-: 0.2
#     o-xxx--o-: 0.2
#     o--xxx-o-: 0.2
#     o--xx-xo-: 0.2
#     o--xx--ox: 0.2
# o--xx---o:
#     ox-xx---o: 0.2
#     o-xxx---o: 0.2
#     o--xxx--o: 0.2
#     o--xx-x-o: 0.2
#     o--xx--xo: 0.2
# oo--xx---:
#     oox-xx---: 0.2
#     oo-xxx---: 0.2
#     oo--xxx--: 0.2
#     oo--xx-x-: 0.2
#     oo--xx--x: 0.2
# o-o-xx---:
#     oxo-xx---: 0.2
#     o-oxxx---: 0.2
#     o-o-xxx--: 0.2
#     o-o-xx-x-: 0.2
#     o-o-xx--x: 0.2
# o--oxx---:
#     ox-oxx---: 0.2
#     o-xoxx---: 0.2
#     o--oxxx--: 0.2
#     o--oxx-x-: 0.2
#     o--oxx--x: 0.2
# o---xxo--:
#     ox--xxo--: 0.2
#     o-x-xxo--: 0.2
#     o--xxxo--: 0.2
#     o---xxox-: 0.2
#     o---xxo-x: 0.2
# o---xx-o-:
#     ox--xx-o-: 0.2
#     o-x-xx-o-: 0.2
#     o--xxx-o-: 0.2
#     o---xxxo-: 0.2
#     o---xx-ox: 0.2
# o---xx--o:
#     ox--xx--o: 0.2
#     o-x-xx--o: 0.2
#     o--xxx--o: 0.2
#     o---xxx-o: 0.2
#     o---xx-xo: 0.2
# oo--x-x--:
#     oox-x-x--: 0.2
#     oo-xx-x--: 0.2
#     oo--xxx--: 0.2
#     oo--x-xx-: 0.2
#     oo--x-x-x: 0.2
# o-o-x-x--:
#     oxo-x-x--: 0.2
#     o-oxx-x--: 0.2
#     o-o-xxx--: 0.2
#     o-o-x-xx-: 0.2
#     o-o-x-x-x: 0.2
# o--ox-x--:
#     ox-ox-x--: 0.2
#     o-xox-x--: 0.2
#     o--oxxx--: 0.2
#     o--ox-xx-: 0.2
#     o--ox-x-x: 0.2
# o---xox--:
#     ox--xox--: 0.2
#     o-x-xox--: 0.2
#     o--xxox--: 0.2
#     o---xoxx-: 0.2
#     o---xox-x: 0.2
# o---x-xo-:
#     ox--x-xo-: 0.2
#     o-x-x-xo-: 0.2
#     o--xx-xo-: 0.2
#     o---xxxo-: 0.2
#     o---x-xox: 0.2
# o---x-x-o:
#     ox--x-x-o: 0.2
#     o-x-x-x-o: 0.2
#     o--xx-x-o: 0.2
#     o---xxx-o: 0.2
#     o---x-xxo: 0.2
# oo--x--x-:
#     oox-x--x-: 0.2
#     oo-xx--x-: 0.2
#     oo--xx-x-: 0.2
#     oo--x-xx-: 0.2
#     oo--x--xx: 0.2
# o-o-x--x-:
#     oxo-x--x-: 0.2
#     o-oxx--x-: 0.2
#     o-o-xx-x-: 0.2
#     o-o-x-xx-: 0.2
#     o-o-x--xx: 0.2
# o--ox--x-:
#     ox-ox--x-: 0.2
#     o-xox--x-: 0.2
#     o--oxx-x-: 0.2
#     o--ox-xx-: 0.2
#     o--ox--xx: 0.2
# o---xo-x-:
#     ox--xo-x-: 0.2
#     o-x-xo-x-: 0.2
#     o--xxo-x-: 0.2
#     o---xoxx-: 0.2
#     o---xo-xx: 0.2
# o---x-ox-:
#     ox--x-ox-: 0.2
#     o-x-x-ox-: 0.2
#     o--xx-ox-: 0.2
#     o---xxox-: 0.2
#     o---x-oxx: 0.2
# o---x--xo:
#     ox--x--xo: 0.2
#     o-x-x--xo: 0.2
#     o--xx--xo: 0.2
#     o---xx-xo: 0.2
#     o---x-xxo: 0.2
# oo--x---x:
#     oox-x---x: 0.2
#     oo-xx---x: 0.2
#     oo--xx--x: 0.2
#     oo--x-x-x: 0.2
#     oo--x--xx: 0.2
# o-o-x---x:
#     oxo-x---x: 0.2
#     o-oxx---x: 0.2
#     o-o-xx--x: 0.2
#     o-o-x-x-x: 0.2
#     o-o-x--xx: 0.2
# o--ox---x:
#     ox-ox---x: 0.2
#     o-xox---x: 0.2
#     o--oxx--x: 0.2
#     o--ox-x-x: 0.2
#     o--ox--xx: 0.2
# o---xo--x:
#     ox--xo--x: 0.2
#     o-x-xo--x: 0.2
#     o--xxo--x: 0.2
#     o---xox-x: 0.2
#     o---xo-xx: 0.2
# o---x-o-x:
#     ox--x-o-x: 0.2
#     o-x-x-o-x: 0.2
#     o--xx-o-x: 0.2
#     o---xxo-x: 0.2
#     o---x-oxx: 0.2
# o---x--ox:
#     ox--x--ox: 0.2
#     o-x-x--ox: 0.2
#     o--xx--ox: 0.2
#     o---xx-ox: 0.2
#     o---x-xox: 0.2
# -oxox----:
#     xoxox----: 0.2
#     -oxoxx---: 0.2
#     -oxox-x--: 0.2
#     -oxox--x-: 0.2
#     -oxox---x: 0.2
# -ox-xo---:
#     xox-xo---: 0.2
#     -oxxxo---: 0.2
#     -ox-xox--: 0.2
#     -ox-xo-x-: 0.2
#     -ox-xo--x: 0.2
# -ox-x-o--:
#     xox-x-o--: 0.2
#     -oxxx-o--: 0.2
#     -ox-xxo--: 0.2
#     -ox-x-ox-: 0.2
#     -ox-x-o-x: 0.2
# -ox-x--o-:
#     xox-x--o-: 0.2
#     -oxxx--o-: 0.2
#     -ox-xx-o-: 0.2
#     -ox-x-xo-: 0.2
#     -ox-x--ox: 0.2
# -ox-x---o:
#     xox-x---o: 0.2
#     -oxxx---o: 0.2
#     -ox-xx--o: 0.2
#     -ox-x-x-o: 0.2
#     -ox-x--xo: 0.2
# -ooxx----:
#     xooxx----: 0.2
#     -ooxxx---: 0.2
#     -ooxx-x--: 0.2
#     -ooxx--x-: 0.2
#     -ooxx---x: 0.2
# -o-xxo---:
#     xo-xxo---: 0.2
#     -oxxxo---: 0.2
#     -o-xxox--: 0.2
#     -o-xxo-x-: 0.2
#     -o-xxo--x: 0.2
# -o-xx-o--:
#     xo-xx-o--: 0.2
#     -oxxx-o--: 0.2
#     -o-xxxo--: 0.2
#     -o-xx-ox-: 0.2
#     -o-xx-o-x: 0.2
# -o-xx--o-:
#     xo-xx--o-: 0.2
#     -oxxx--o-: 0.2
#     -o-xxx-o-: 0.2
#     -o-xx-xo-: 0.2
#     -o-xx--ox: 0.2
# -o-xx---o:
#     xo-xx---o: 0.2
#     -oxxx---o: 0.2
#     -o-xxx--o: 0.2
#     -o-xx-x-o: 0.2
#     -o-xx--xo: 0.2
# -oo-xx---:
#     xoo-xx---: 0.2
#     -ooxxx---: 0.2
#     -oo-xxx--: 0.2
#     -oo-xx-x-: 0.2
#     -oo-xx--x: 0.2
# -o-oxx---:
#     xo-oxx---: 0.2
#     -oxoxx---: 0.2
#     -o-oxxx--: 0.2
#     -o-oxx-x-: 0.2
#     -o-oxx--x: 0.2
# -o--xxo--:
#     xo--xxo--: 0.2
#     -ox-xxo--: 0.2
#     -o-xxxo--: 0.2
#     -o--xxox-: 0.2
#     -o--xxo-x: 0.2
# -o--xx-o-:
#     xo--xx-o-: 0.2
#     -ox-xx-o-: 0.2
#     -o-xxx-o-: 0.2
#     -o--xxxo-: 0.2
#     -o--xx-ox: 0.2
# -o--xx--o:
#     xo--xx--o: 0.2
#     -ox-xx--o: 0.2
#     -o-xxx--o: 0.2
#     -o--xxx-o: 0.2
#     -o--xx-xo: 0.2
# -oo-x-x--:
#     xoo-x-x--: 0.2
#     -ooxx-x--: 0.2
#     -oo-xxx--: 0.2
#     -oo-x-xx-: 0.2
#     -oo-x-x-x: 0.2
# -o-ox-x--:
#     xo-ox-x--: 0.2
#     -oxox-x--: 0.2
#     -o-oxxx--: 0.2
#     -o-ox-xx-: 0.2
#     -o-ox-x-x: 0.2
# -o--xox--:
#     xo--xox--: 0.2
#     -ox-xox--: 0.2
#     -o-xxox--: 0.2
#     -o--xoxx-: 0.2
#     -o--xox-x: 0.2
# -o--x-xo-:
#     xo--x-xo-: 0.2
#     -ox-x-xo-: 0.2
#     -o-xx-xo-: 0.2
#     -o--xxxo-: 0.2
#     -o--x-xox: 0.2
# -o--x-x-o:
#     xo--x-x-o: 0.2
#     -ox-x-x-o: 0.2
#     -o-xx-x-o: 0.2
#     -o--xxx-o: 0.2
#     -o--x-xxo: 0.2
# -oo-x--x-:
#     xoo-x--x-: 0.2
#     -ooxx--x-: 0.2
#     -oo-xx-x-: 0.2
#     -oo-x-xx-: 0.2
#     -oo-x--xx: 0.2
# -o-ox--x-:
#     xo-ox--x-: 0.2
#     -oxox--x-: 0.2
#     -o-oxx-x-: 0.2
#     -o-ox-xx-: 0.2
#     -o-ox--xx: 0.2
# -o--xo-x-:
#     xo--xo-x-: 0.2
#     -ox-xo-x-: 0.2
#     -o-xxo-x-: 0.2
#     -o--xoxx-: 0.2
#     -o--xo-xx: 0.2
# -o--x-ox-:
#     xo--x-ox-: 0.2
#     -ox-x-ox-: 0.2
#     -o-xx-ox-: 0.2
#     -o--xxox-: 0.2
#     -o--x-oxx: 0.2
# -o--x--xo:
#     xo--x--xo: 0.2
#     -ox-x--xo: 0.2
#     -o-xx--xo: 0.2
#     -o--xx-xo: 0.2
#     -o--x-xxo: 0.2
# -oo-x---x:
#     xoo-x---x: 0.2
#     -ooxx---x: 0.2
#     -oo-xx--x: 0.2
#     -oo-x-x-x: 0.2
#     -oo-x--xx: 0.2
# -o-ox---x:
#     xo-ox---x: 0.2
#     -oxox---x: 0.2
#     -o-oxx--x: 0.2
#     -o-ox-x-x: 0.2
#     -o-ox--xx: 0.2
# -o--xo--x:
#     xo--xo--x: 0.2
#     -ox-xo--x: 0.2
#     -o-xxo--x: 0.2
#     -o--xox-x: 0.2
#     -o--xo-xx: 0.2
# -o--x-o-x:
#     xo--x-o-x: 0.2
#     -ox-x-o-x: 0.2
#     -o-xx-o-x: 0.2
#     -o--xxo-x: 0.2
#     -o--x-oxx: 0.2
# -o--x--ox:
#     xo--x--ox: 0.2
#     -ox-x--ox: 0.2
#     -o-xx--ox: 0.2
#     -o--xx-ox: 0.2
#     -o--x-xox: 0.2
# Turn 6 ====================================
# xoxoxo---:
#     xoxoxox--: 0.3333333333333333
#     xoxoxo-x-: 0.3333333333333333
#     xoxoxo--x: 0.3333333333333333
# xoxox-o--:
#     xoxoxxo--: 0.3333333333333333
#     xoxox-ox-: 0.3333333333333333
#     xoxox-o-x: 0.3333333333333333
# xoxox--o-:
#     xoxoxx-o-: 0.3333333333333333
#     xoxox-xo-: 0.3333333333333333
#     xoxox--ox: 0.3333333333333333
# xoxox---o:
#     xoxoxx--o: 0.3333333333333333
#     xoxox-x-o: 0.3333333333333333
#     xoxox--xo: 0.3333333333333333
# xoxoox---:
#     xoxooxx--: 0.3333333333333333
#     xoxoox-x-: 0.3333333333333333
#     xoxoox--x: 0.3333333333333333
# xoxo-xo--:
#     xoxoxxo--: 0.3333333333333333
#     xoxo-xox-: 0.3333333333333333
#     xoxo-xo-x: 0.3333333333333333
# xoxo-x-o-:
#     xoxoxx-o-: 0.3333333333333333
#     xoxo-xxo-: 0.3333333333333333
#     xoxo-x-ox: 0.3333333333333333
# xoxo-x--o:
#     xoxoxx--o: 0.3333333333333333
#     xoxo-xx-o: 0.3333333333333333
#     xoxo-x-xo: 0.3333333333333333
# xoxoo-x--:
#     xoxooxx--: 0.3333333333333333
#     xoxoo-xx-: 0.3333333333333333
#     xoxoo-x-x: 0.3333333333333333
# xoxo-ox--:
#     xoxoxox--: 0.3333333333333333
#     xoxo-oxx-: 0.3333333333333333
#     xoxo-ox-x: 0.3333333333333333
# xoxo--xo-:
#     xoxox-xo-: 0.3333333333333333
#     xoxo-xxo-: 0.3333333333333333
#     xoxo--xox: 0.3333333333333333
# xoxo--x-o:
#     xoxox-x-o: 0.3333333333333333
#     xoxo-xx-o: 0.3333333333333333
#     xoxo--xxo: 0.3333333333333333
# xoxoo--x-:
#     xoxoox-x-: 0.3333333333333333
#     xoxoo-xx-: 0.3333333333333333
#     xoxoo--xx: 0.3333333333333333
# xoxo-o-x-:
#     xoxoxo-x-: 0.3333333333333333
#     xoxo-oxx-: 0.3333333333333333
#     xoxo-o-xx: 0.3333333333333333
# xoxo--ox-:
#     xoxox-ox-: 0.3333333333333333
#     xoxo-xox-: 0.3333333333333333
#     xoxo--oxx: 0.3333333333333333
# xoxo---xo:
#     xoxox--xo: 0.3333333333333333
#     xoxo-x-xo: 0.3333333333333333
#     xoxo--xxo: 0.3333333333333333
# xoxoo---x:
#     xoxoox--x: 0.3333333333333333
#     xoxoo-x-x: 0.3333333333333333
#     xoxoo--xx: 0.3333333333333333
# xoxo-o--x:
#     xoxoxo--x: 0.3333333333333333
#     xoxo-ox-x: 0.3333333333333333
#     xoxo-o-xx: 0.3333333333333333
# xoxo--o-x:
#     xoxox-o-x: 0.3333333333333333
#     xoxo-xo-x: 0.3333333333333333
#     xoxo--oxx: 0.3333333333333333
# xoxo---ox:
#     xoxox--ox: 0.3333333333333333
#     xoxo-x-ox: 0.3333333333333333
#     xoxo--xox: 0.3333333333333333
# xoxxoo---:
#     xoxxoox--: 0.3333333333333333
#     xoxxoo-x-: 0.3333333333333333
#     xoxxoo--x: 0.3333333333333333
# xoxxo-o--:
#     xoxxoxo--: 0.3333333333333333
#     xoxxo-ox-: 0.3333333333333333
#     xoxxo-o-x: 0.3333333333333333
# xoxxo---o:
#     xoxxox--o: 0.3333333333333333
#     xoxxo-x-o: 0.3333333333333333
#     xoxxo--xo: 0.3333333333333333
# ...
#     o-oxx-xxo: 0.3333333333333333
# o-oxxo--x:
#     oxoxxo--x: 0.3333333333333333
#     o-oxxox-x: 0.3333333333333333
#     o-oxxo-xx: 0.3333333333333333
# o-oxx-o-x:
#     oxoxx-o-x: 0.3333333333333333
#     o-oxxxo-x: 0.3333333333333333
#     o-oxx-oxx: 0.3333333333333333
# o-oxx--ox:
#     oxoxx--ox: 0.3333333333333333
#     o-oxxx-ox: 0.3333333333333333
#     o-oxx-xox: 0.3333333333333333
# o--xxoxo-:
#     ox-xxoxo-: 0.3333333333333333
#     o-xxxoxo-: 0.3333333333333333
#     o--xxoxox: 0.3333333333333333
# o--xxox-o:
#     ox-xxox-o: 0.3333333333333333
#     o-xxxox-o: 0.3333333333333333
#     o--xxoxxo: 0.3333333333333333
# o--xxoox-:
#     ox-xxoox-: 0.3333333333333333
#     o-xxxoox-: 0.3333333333333333
#     o--xxooxx: 0.3333333333333333
# o--xxo-xo:
#     ox-xxo-xo: 0.3333333333333333
#     o-xxxo-xo: 0.3333333333333333
#     o--xxoxxo: 0.3333333333333333
# o--xxoo-x:
#     ox-xxoo-x: 0.3333333333333333
#     o-xxxoo-x: 0.3333333333333333
#     o--xxooxx: 0.3333333333333333
# o--xxo-ox:
#     ox-xxo-ox: 0.3333333333333333
#     o-xxxo-ox: 0.3333333333333333
#     o--xxoxox: 0.3333333333333333
# o--xx-oxo:
#     ox-xx-oxo: 0.3333333333333333
#     o-xxx-oxo: 0.3333333333333333
#     o--xxxoxo: 0.3333333333333333
# o--xx-oox:
#     ox-xx-oox: 0.3333333333333333
#     o-xxx-oox: 0.3333333333333333
#     o--xxxoox: 0.3333333333333333
# o--xx-xoo:
#     ox-xx-xoo: 0.3333333333333333
#     o-xxx-xoo: 0.3333333333333333
#     o--xxxxoo: 0.3333333333333333
# oo-oxxx--:
#     ooxoxxx--: 0.3333333333333333
#     oo-oxxxx-: 0.3333333333333333
#     oo-oxxx-x: 0.3333333333333333
# oo--xxxo-:
#     oox-xxxo-: 0.3333333333333333
#     oo-xxxxo-: 0.3333333333333333
#     oo--xxxox: 0.3333333333333333
# oo--xxx-o:
#     oox-xxx-o: 0.3333333333333333
#     oo-xxxx-o: 0.3333333333333333
#     oo--xxxxo: 0.3333333333333333
# oo-oxx-x-:
#     ooxoxx-x-: 0.3333333333333333
#     oo-oxxxx-: 0.3333333333333333
#     oo-oxx-xx: 0.3333333333333333
# oo--xxox-:
#     oox-xxox-: 0.3333333333333333
#     oo-xxxox-: 0.3333333333333333
#     oo--xxoxx: 0.3333333333333333
# oo--xx-xo:
#     oox-xx-xo: 0.3333333333333333
#     oo-xxx-xo: 0.3333333333333333
#     oo--xxxxo: 0.3333333333333333
# oo-oxx--x:
#     ooxoxx--x: 0.3333333333333333
#     oo-oxxx-x: 0.3333333333333333
#     oo-oxx-xx: 0.3333333333333333
# oo--xxo-x:
#     oox-xxo-x: 0.3333333333333333
#     oo-xxxo-x: 0.3333333333333333
#     oo--xxoxx: 0.3333333333333333
# oo--xx-ox:
#     oox-xx-ox: 0.3333333333333333
#     oo-xxx-ox: 0.3333333333333333
#     oo--xxxox: 0.3333333333333333
# o-ooxxx--:
#     oxooxxx--: 0.3333333333333333
#     o-ooxxxx-: 0.3333333333333333
#     o-ooxxx-x: 0.3333333333333333
# o-o-xxxo-:
#     oxo-xxxo-: 0.3333333333333333
#     o-oxxxxo-: 0.3333333333333333
#     o-o-xxxox: 0.3333333333333333
# o-o-xxx-o:
#     oxo-xxx-o: 0.3333333333333333
#     o-oxxxx-o: 0.3333333333333333
#     o-o-xxxxo: 0.3333333333333333
# o-ooxx-x-:
#     oxooxx-x-: 0.3333333333333333
#     o-ooxxxx-: 0.3333333333333333
#     o-ooxx-xx: 0.3333333333333333
# o-o-xxox-:
#     oxo-xxox-: 0.3333333333333333
#     o-oxxxox-: 0.3333333333333333
#     o-o-xxoxx: 0.3333333333333333
# o-o-xx-xo:
#     oxo-xx-xo: 0.3333333333333333
#     o-oxxx-xo: 0.3333333333333333
#     o-o-xxxxo: 0.3333333333333333
# o-ooxx--x:
#     oxooxx--x: 0.3333333333333333
#     o-ooxxx-x: 0.3333333333333333
#     o-ooxx-xx: 0.3333333333333333
# o-o-xxo-x:
#     oxo-xxo-x: 0.3333333333333333
#     o-oxxxo-x: 0.3333333333333333
#     o-o-xxoxx: 0.3333333333333333
# o-o-xx-ox:
#     oxo-xx-ox: 0.3333333333333333
#     o-oxxx-ox: 0.3333333333333333
#     o-o-xxxox: 0.3333333333333333
# o--oxxxo-:
#     ox-oxxxo-: 0.3333333333333333
#     o-xoxxxo-: 0.3333333333333333
#     o--oxxxox: 0.3333333333333333
# o--oxxx-o:
#     ox-oxxx-o: 0.3333333333333333
#     o-xoxxx-o: 0.3333333333333333
#     o--oxxxxo: 0.3333333333333333
# o--oxx-xo:
#     ox-oxx-xo: 0.3333333333333333
#     o-xoxx-xo: 0.3333333333333333
#     o--oxxxxo: 0.3333333333333333
# o--oxx-ox:
#     ox-oxx-ox: 0.3333333333333333
#     o-xoxx-ox: 0.3333333333333333
#     o--oxxxox: 0.3333333333333333
# o---xxoxo:
#     ox--xxoxo: 0.3333333333333333
#     o-x-xxoxo: 0.3333333333333333
#     o--xxxoxo: 0.3333333333333333
# o---xxoox:
#     ox--xxoox: 0.3333333333333333
#     o-x-xxoox: 0.3333333333333333
#     o--xxxoox: 0.3333333333333333
# o---xxxoo:
#     ox--xxxoo: 0.3333333333333333
#     o-x-xxxoo: 0.3333333333333333
#     o--xxxxoo: 0.3333333333333333
# oo-ox-xx-:
#     ooxox-xx-: 0.3333333333333333
#     oo-oxxxx-: 0.3333333333333333
#     oo-ox-xxx: 0.3333333333333333
# oo--xoxx-:
#     oox-xoxx-: 0.3333333333333333
#     oo-xxoxx-: 0.3333333333333333
#     oo--xoxxx: 0.3333333333333333
# oo--x-xxo:
#     oox-x-xxo: 0.3333333333333333
#     oo-xx-xxo: 0.3333333333333333
#     oo--xxxxo: 0.3333333333333333
# oo-ox-x-x:
#     ooxox-x-x: 0.3333333333333333
#     oo-oxxx-x: 0.3333333333333333
#     oo-ox-xxx: 0.3333333333333333
# oo--xox-x:
#     oox-xox-x: 0.3333333333333333
#     oo-xxox-x: 0.3333333333333333
#     oo--xoxxx: 0.3333333333333333
# oo--x-xox:
#     oox-x-xox: 0.3333333333333333
#     oo-xx-xox: 0.3333333333333333
#     oo--xxxox: 0.3333333333333333
# o-oox-xx-:
#     oxoox-xx-: 0.3333333333333333
#     o-ooxxxx-: 0.3333333333333333
#     o-oox-xxx: 0.3333333333333333
# o-o-xoxx-:
#     oxo-xoxx-: 0.3333333333333333
#     o-oxxoxx-: 0.3333333333333333
#     o-o-xoxxx: 0.3333333333333333
# o-o-x-xxo:
#     oxo-x-xxo: 0.3333333333333333
#     o-oxx-xxo: 0.3333333333333333
#     o-o-xxxxo: 0.3333333333333333
# o-oox-x-x:
#     oxoox-x-x: 0.3333333333333333
#     o-ooxxx-x: 0.3333333333333333
#     o-oox-xxx: 0.3333333333333333
# o-o-xox-x:
#     oxo-xox-x: 0.3333333333333333
#     o-oxxox-x: 0.3333333333333333
#     o-o-xoxxx: 0.3333333333333333
# o-o-x-xox:
#     oxo-x-xox: 0.3333333333333333
#     o-oxx-xox: 0.3333333333333333
#     o-o-xxxox: 0.3333333333333333
# o--oxoxx-:
#     ox-oxoxx-: 0.3333333333333333
#     o-xoxoxx-: 0.3333333333333333
#     o--oxoxxx: 0.3333333333333333
# o--ox-xxo:
#     ox-ox-xxo: 0.3333333333333333
#     o-xox-xxo: 0.3333333333333333
#     o--oxxxxo: 0.3333333333333333
# o--oxox-x:
#     ox-oxox-x: 0.3333333333333333
#     o-xoxox-x: 0.3333333333333333
#     o--oxoxxx: 0.3333333333333333
# o--ox-xox:
#     ox-ox-xox: 0.3333333333333333
#     o-xox-xox: 0.3333333333333333
#     o--oxxxox: 0.3333333333333333
# o---xoxxo:
#     ox--xoxxo: 0.3333333333333333
#     o-x-xoxxo: 0.3333333333333333
#     o--xxoxxo: 0.3333333333333333
# o---xoxox:
#     ox--xoxox: 0.3333333333333333
#     o-x-xoxox: 0.3333333333333333
#     o--xxoxox: 0.3333333333333333
# oo-ox--xx:
#     ooxox--xx: 0.3333333333333333
#     oo-oxx-xx: 0.3333333333333333
#     oo-ox-xxx: 0.3333333333333333
# oo--xo-xx:
#     oox-xo-xx: 0.3333333333333333
#     oo-xxo-xx: 0.3333333333333333
#     oo--xoxxx: 0.3333333333333333
# oo--x-oxx:
#     oox-x-oxx: 0.3333333333333333
#     oo-xx-oxx: 0.3333333333333333
#     oo--xxoxx: 0.3333333333333333
# o-oox--xx:
#     oxoox--xx: 0.3333333333333333
#     o-ooxx-xx: 0.3333333333333333
#     o-oox-xxx: 0.3333333333333333
# o-o-xo-xx:
#     oxo-xo-xx: 0.3333333333333333
#     o-oxxo-xx: 0.3333333333333333
#     o-o-xoxxx: 0.3333333333333333
# o-o-x-oxx:
#     oxo-x-oxx: 0.3333333333333333
#     o-oxx-oxx: 0.3333333333333333
#     o-o-xxoxx: 0.3333333333333333
# o--oxo-xx:
#     ox-oxo-xx: 0.3333333333333333
#     o-xoxo-xx: 0.3333333333333333
#     o--oxoxxx: 0.3333333333333333
# o---xooxx:
#     ox--xooxx: 0.3333333333333333
#     o-x-xooxx: 0.3333333333333333
#     o--xxooxx: 0.3333333333333333
# -oxoxxo--:
#     xoxoxxo--: 0.3333333333333333
#     -oxoxxox-: 0.3333333333333333
#     -oxoxxo-x: 0.3333333333333333
# -oxoxx-o-:
#     xoxoxx-o-: 0.3333333333333333
#     -oxoxxxo-: 0.3333333333333333
#     -oxoxx-ox: 0.3333333333333333
# -oxoxx--o:
#     xoxoxx--o: 0.3333333333333333
#     -oxoxxx-o: 0.3333333333333333
#     -oxoxx-xo: 0.3333333333333333
# -oxoxo-x-:
#     xoxoxo-x-: 0.3333333333333333
#     -oxoxoxx-: 0.3333333333333333
#     -oxoxo-xx: 0.3333333333333333
# -oxox-ox-:
#     xoxox-ox-: 0.3333333333333333
#     -oxoxxox-: 0.3333333333333333
#     -oxox-oxx: 0.3333333333333333
# -oxox--xo:
#     xoxox--xo: 0.3333333333333333
#     -oxoxx-xo: 0.3333333333333333
#     -oxox-xxo: 0.3333333333333333
# -oxoxo--x:
#     xoxoxo--x: 0.3333333333333333
#     -oxoxox-x: 0.3333333333333333
#     -oxoxo-xx: 0.3333333333333333
# -oxox-o-x:
#     xoxox-o-x: 0.3333333333333333
#     -oxoxxo-x: 0.3333333333333333
#     -oxox-oxx: 0.3333333333333333
# -oxox--ox:
#     xoxox--ox: 0.3333333333333333
#     -oxoxx-ox: 0.3333333333333333
#     -oxox-xox: 0.3333333333333333
# -oxxxoo--:
#     xoxxxoo--: 0.3333333333333333
#     -oxxxoox-: 0.3333333333333333
#     -oxxxoo-x: 0.3333333333333333
# -oxxxo-o-:
#     xoxxxo-o-: 0.3333333333333333
#     -oxxxoxo-: 0.3333333333333333
#     -oxxxo-ox: 0.3333333333333333
# -oxxxo--o:
#     xoxxxo--o: 0.3333333333333333
#     -oxxxox-o: 0.3333333333333333
#     -oxxxo-xo: 0.3333333333333333
# -ox-xoox-:
#     xox-xoox-: 0.3333333333333333
#     -oxxxoox-: 0.3333333333333333
#     -ox-xooxx: 0.3333333333333333
# -ox-xo-xo:
#     xox-xo-xo: 0.3333333333333333
#     -oxxxo-xo: 0.3333333333333333
#     -ox-xoxxo: 0.3333333333333333
# -ox-xoo-x:
#     xox-xoo-x: 0.3333333333333333
#     -oxxxoo-x: 0.3333333333333333
#     -ox-xooxx: 0.3333333333333333
# -ox-xo-ox:
#     xox-xo-ox: 0.3333333333333333
#     -oxxxo-ox: 0.3333333333333333
#     -ox-xoxox: 0.3333333333333333
# -oxxx-oo-:
#     xoxxx-oo-: 0.3333333333333333
#     -oxxxxoo-: 0.3333333333333333
#     -oxxx-oox: 0.3333333333333333
# -oxxx-o-o:
#     xoxxx-o-o: 0.3333333333333333
#     -oxxxxo-o: 0.3333333333333333
#     -oxxx-oxo: 0.3333333333333333
# -ox-xxoo-:
#     xox-xxoo-: 0.3333333333333333
#     -oxxxxoo-: 0.3333333333333333
#     -ox-xxoox: 0.3333333333333333
# -ox-xxo-o:
#     xox-xxo-o: 0.3333333333333333
#     -oxxxxo-o: 0.3333333333333333
#     -ox-xxoxo: 0.3333333333333333
# -ox-x-oxo:
#     xox-x-oxo: 0.3333333333333333
#     -oxxx-oxo: 0.3333333333333333
#     -ox-xxoxo: 0.3333333333333333
# -ox-x-oox:
#     xox-x-oox: 0.3333333333333333
#     -oxxx-oox: 0.3333333333333333
#     -ox-xxoox: 0.3333333333333333
# -oxxx--oo:
#     xoxxx--oo: 0.3333333333333333
#     -oxxxx-oo: 0.3333333333333333
#     -oxxx-xoo: 0.3333333333333333
# -ox-xx-oo:
#     xox-xx-oo: 0.3333333333333333
#     -oxxxx-oo: 0.3333333333333333
#     -ox-xxxoo: 0.3333333333333333
# -ooxxox--:
#     xooxxox--: 0.3333333333333333
#     -ooxxoxx-: 0.3333333333333333
#     -ooxxox-x: 0.3333333333333333
# -ooxx-xo-:
#     xooxx-xo-: 0.3333333333333333
#     -ooxxxxo-: 0.3333333333333333
#     -ooxx-xox: 0.3333333333333333
# -ooxx-x-o:
#     xooxx-x-o: 0.3333333333333333
#     -ooxxxx-o: 0.3333333333333333
#     -ooxx-xxo: 0.3333333333333333
# -ooxxo-x-:
#     xooxxo-x-: 0.3333333333333333
#     -ooxxoxx-: 0.3333333333333333
#     -ooxxo-xx: 0.3333333333333333
# -ooxx-ox-:
#     xooxx-ox-: 0.3333333333333333
#     -ooxxxox-: 0.3333333333333333
#     -ooxx-oxx: 0.3333333333333333
# -ooxx--xo:
#     xooxx--xo: 0.3333333333333333
#     -ooxxx-xo: 0.3333333333333333
#     -ooxx-xxo: 0.3333333333333333
# -ooxxo--x:
#     xooxxo--x: 0.3333333333333333
#     -ooxxox-x: 0.3333333333333333
#     -ooxxo-xx: 0.3333333333333333
# -ooxx-o-x:
#     xooxx-o-x: 0.3333333333333333
#     -ooxxxo-x: 0.3333333333333333
#     -ooxx-oxx: 0.3333333333333333
# -ooxx--ox:
#     xooxx--ox: 0.3333333333333333
#     -ooxxx-ox: 0.3333333333333333
#     -ooxx-xox: 0.3333333333333333
# -o-xxoxo-:
#     xo-xxoxo-: 0.3333333333333333
#     -oxxxoxo-: 0.3333333333333333
#     -o-xxoxox: 0.3333333333333333
# -o-xxox-o:
#     xo-xxox-o: 0.3333333333333333
#     -oxxxox-o: 0.3333333333333333
#     -o-xxoxxo: 0.3333333333333333
# -o-xxoox-:
#     xo-xxoox-: 0.3333333333333333
#     -oxxxoox-: 0.3333333333333333
#     -o-xxooxx: 0.3333333333333333
# -o-xxo-xo:
#     xo-xxo-xo: 0.3333333333333333
#     -oxxxo-xo: 0.3333333333333333
#     -o-xxoxxo: 0.3333333333333333
# -o-xxoo-x:
#     xo-xxoo-x: 0.3333333333333333
#     -oxxxoo-x: 0.3333333333333333
#     -o-xxooxx: 0.3333333333333333
# -o-xxo-ox:
#     xo-xxo-ox: 0.3333333333333333
#     -oxxxo-ox: 0.3333333333333333
#     -o-xxoxox: 0.3333333333333333
# -o-xx-oxo:
#     xo-xx-oxo: 0.3333333333333333
#     -oxxx-oxo: 0.3333333333333333
#     -o-xxxoxo: 0.3333333333333333
# -o-xx-oox:
#     xo-xx-oox: 0.3333333333333333
#     -oxxx-oox: 0.3333333333333333
#     -o-xxxoox: 0.3333333333333333
# -o-xx-xoo:
#     xo-xx-xoo: 0.3333333333333333
#     -oxxx-xoo: 0.3333333333333333
#     -o-xxxxoo: 0.3333333333333333
# -oooxxx--:
#     xoooxxx--: 0.3333333333333333
#     -oooxxxx-: 0.3333333333333333
#     -oooxxx-x: 0.3333333333333333
# -oo-xxxo-:
#     xoo-xxxo-: 0.3333333333333333
#     -ooxxxxo-: 0.3333333333333333
#     -oo-xxxox: 0.3333333333333333
# -oo-xxx-o:
#     xoo-xxx-o: 0.3333333333333333
#     -ooxxxx-o: 0.3333333333333333
#     -oo-xxxxo: 0.3333333333333333
# -oooxx-x-:
#     xoooxx-x-: 0.3333333333333333
#     -oooxxxx-: 0.3333333333333333
#     -oooxx-xx: 0.3333333333333333
# -oo-xxox-:
#     xoo-xxox-: 0.3333333333333333
#     -ooxxxox-: 0.3333333333333333
#     -oo-xxoxx: 0.3333333333333333
# -oo-xx-xo:
#     xoo-xx-xo: 0.3333333333333333
#     -ooxxx-xo: 0.3333333333333333
#     -oo-xxxxo: 0.3333333333333333
# -oooxx--x:
#     xoooxx--x: 0.3333333333333333
#     -oooxxx-x: 0.3333333333333333
#     -oooxx-xx: 0.3333333333333333
# -oo-xxo-x:
#     xoo-xxo-x: 0.3333333333333333
#     -ooxxxo-x: 0.3333333333333333
#     -oo-xxoxx: 0.3333333333333333
# -oo-xx-ox:
#     xoo-xx-ox: 0.3333333333333333
#     -ooxxx-ox: 0.3333333333333333
#     -oo-xxxox: 0.3333333333333333
# -o-oxxxo-:
#     xo-oxxxo-: 0.3333333333333333
#     -oxoxxxo-: 0.3333333333333333
#     -o-oxxxox: 0.3333333333333333
# -o-oxxx-o:
#     xo-oxxx-o: 0.3333333333333333
#     -oxoxxx-o: 0.3333333333333333
#     -o-oxxxxo: 0.3333333333333333
# -o-oxxox-:
#     xo-oxxox-: 0.3333333333333333
#     -oxoxxox-: 0.3333333333333333
#     -o-oxxoxx: 0.3333333333333333
# -o-oxx-xo:
#     xo-oxx-xo: 0.3333333333333333
#     -oxoxx-xo: 0.3333333333333333
#     -o-oxxxxo: 0.3333333333333333
# -o-oxxo-x:
#     xo-oxxo-x: 0.3333333333333333
#     -oxoxxo-x: 0.3333333333333333
#     -o-oxxoxx: 0.3333333333333333
# -o-oxx-ox:
#     xo-oxx-ox: 0.3333333333333333
#     -oxoxx-ox: 0.3333333333333333
#     -o-oxxxox: 0.3333333333333333
# -o--xxoxo:
#     xo--xxoxo: 0.3333333333333333
#     -ox-xxoxo: 0.3333333333333333
#     -o-xxxoxo: 0.3333333333333333
# -o--xxoox:
#     xo--xxoox: 0.3333333333333333
#     -ox-xxoox: 0.3333333333333333
#     -o-xxxoox: 0.3333333333333333
# -o--xxxoo:
#     xo--xxxoo: 0.3333333333333333
#     -ox-xxxoo: 0.3333333333333333
#     -o-xxxxoo: 0.3333333333333333
# -ooox-xx-:
#     xooox-xx-: 0.3333333333333333
#     -oooxxxx-: 0.3333333333333333
#     -ooox-xxx: 0.3333333333333333
# -oo-xoxx-:
#     xoo-xoxx-: 0.3333333333333333
#     -ooxxoxx-: 0.3333333333333333
#     -oo-xoxxx: 0.3333333333333333
# -oo-x-xxo:
#     xoo-x-xxo: 0.3333333333333333
#     -ooxx-xxo: 0.3333333333333333
#     -oo-xxxxo: 0.3333333333333333
# -ooox-x-x:
#     xooox-x-x: 0.3333333333333333
#     -oooxxx-x: 0.3333333333333333
#     -ooox-xxx: 0.3333333333333333
# -oo-xox-x:
#     xoo-xox-x: 0.3333333333333333
#     -ooxxox-x: 0.3333333333333333
#     -oo-xoxxx: 0.3333333333333333
# -oo-x-xox:
#     xoo-x-xox: 0.3333333333333333
#     -ooxx-xox: 0.3333333333333333
#     -oo-xxxox: 0.3333333333333333
# -o-oxoxx-:
#     xo-oxoxx-: 0.3333333333333333
#     -oxoxoxx-: 0.3333333333333333
#     -o-oxoxxx: 0.3333333333333333
# -o-ox-xxo:
#     xo-ox-xxo: 0.3333333333333333
#     -oxox-xxo: 0.3333333333333333
#     -o-oxxxxo: 0.3333333333333333
# -o-oxox-x:
#     xo-oxox-x: 0.3333333333333333
#     -oxoxox-x: 0.3333333333333333
#     -o-oxoxxx: 0.3333333333333333
# -o-ox-xox:
#     xo-ox-xox: 0.3333333333333333
#     -oxox-xox: 0.3333333333333333
#     -o-oxxxox: 0.3333333333333333
# -o--xoxxo:
#     xo--xoxxo: 0.3333333333333333
#     -ox-xoxxo: 0.3333333333333333
#     -o-xxoxxo: 0.3333333333333333
# -o--xoxox:
#     xo--xoxox: 0.3333333333333333
#     -ox-xoxox: 0.3333333333333333
#     -o-xxoxox: 0.3333333333333333
# -ooox--xx:
#     xooox--xx: 0.3333333333333333
#     -oooxx-xx: 0.3333333333333333
#     -ooox-xxx: 0.3333333333333333
# -oo-xo-xx:
#     xoo-xo-xx: 0.3333333333333333
#     -ooxxo-xx: 0.3333333333333333
#     -oo-xoxxx: 0.3333333333333333
# -oo-x-oxx:
#     xoo-x-oxx: 0.3333333333333333
#     -ooxx-oxx: 0.3333333333333333
#     -oo-xxoxx: 0.3333333333333333
# -o-oxo-xx:
#     xo-oxo-xx: 0.3333333333333333
#     -oxoxo-xx: 0.3333333333333333
#     -o-oxoxxx: 0.3333333333333333
# -o-ox-oxx:
#     xo-ox-oxx: 0.3333333333333333
#     -oxox-oxx: 0.3333333333333333
#     -o-oxxoxx: 0.3333333333333333
# -o--xooxx:
#     xo--xooxx: 0.3333333333333333
#     -ox-xooxx: 0.3333333333333333
#     -o-xxooxx: 0.3333333333333333
